# %%
from obspy import read, Stream, UTCDateTime
import numpy as np
from mudpy.hfsims import windowed_gaussian, apply_spectrum
from mudpy.forward import gnss_psd
import matplotlib.pyplot as plt
import h5py
from glob import glob

# %%
project_name = 'newfault'
GF_list = 'rc_gflist.gflist' # Station file used in fq gen code
vel_mod = 'mojave'
stas_name = GF_list.split('.')[0]
fq_dir = '/hdd/rc_fq/fall24/' + project_name + '/'
arrival_save_dir = '/hdd/rc_fq/fall24/' + project_name + '_fq_parrivals/'

ruptures = np.load('/hdd/rc_fq/fall24/' + project_name + '_ruptures.npy')
test_ruptures = ['newfault.000000']

stas = np.load('/hdd/rc_fq/fall24/' + stas_name + '_station_names.npy')
test_stas = ['P595', 'P594', 'CCCC']
# print(stas)

# %%
data_list = []

mag_list = []
sta_list = []
rupt_list = []

counter = 0

for rupt in ruptures:
# for krupt in range(len(test_rupts)):
    
    counter += 1
    if counter % 10 == 0:
        print('Rupture ' + rupt + ' (' + str(counter) + '/' + str(len(ruptures)) + ')')
    
    log = glob(fq_dir + 'output/ruptures/' + rupt + '.log')
    log = open(log[0],'r')
    line = log.readlines()
    
    mag = str(line[15][21:27])
#     print(mag)
    
    for sta in stas:
        
#         print(sta)
        arrivals = np.genfromtxt(arrival_save_dir + stas_name + '_arrival_times_' + rupt + '.csv', dtype = 'U')
#         print(arrivals)
            
        # Read in data 
        
        stN = read(fq_dir + 'output/waveforms/' + rupt + '/' + sta + '.LYN.sac') 
        stE = read(fq_dir + 'output/waveforms/' + rupt + '/' + sta + '.LYE.sac') 
        stZ = read(fq_dir + 'output/waveforms/' + rupt + '/' + sta + '.LYZ.sac') 
        
#         print(stN[0].stats.starttime)
        
#         stN.plot()
        
        N_data = stN[0].data
        E_data = stE[0].data
        Z_data = stZ[0].data
        
        ### Zero-pad this data ###
        
        N_data_padded = np.pad(N_data, 128, mode = 'constant')
        E_data_padded = np.pad(E_data, 128, mode = 'constant')
        Z_data_padded = np.pad(Z_data, 128, mode = 'constant')
        
        stN_pad = stN.copy()
        stN_pad[0].data = N_data_padded
        
        stE_pad = stE.copy()
        stE_pad[0].data = E_data_padded
        
        stZ_pad = stZ.copy()
        stZ_pad[0].data = Z_data_padded
        
#         stN.plot()
#         stN_pad.plot()
#         print(stN_pad[0].stats.starttime)
        
        npts = stN_pad[0].stats.npts

        ### Trim around the arrival time ###
        
        stas_arrival = arrivals[:,1] # Station list from arrivals file
        
        i = np.where(stas_arrival == sta)[0]
        arrival = arrivals[i,2][0]
#         print(arrival)

        # Grab the arrival time

        arr_time = UTCDateTime(arrival)
        arr_time = arr_time + 128 # To account for padding at front
        starttime = arr_time - 128
        endtime = arr_time + 127 # Needs to be 256 samples, not 256 seconds

#         arr_time = arr_time + 3 # To account for padding at front
#         starttime = arr_time - 3
#         endtime = arr_time + 3
        
#         print(starttime)
#         print(arr_time)
#         print(endtime)
        
        stN_trim = stN_pad.trim(starttime, endtime)
        stE_trim = stE_pad.trim(starttime, endtime)
        stZ_trim = stZ_pad.trim(starttime, endtime)
        
        stN_trim_data = stN_trim[0].data # Middle sample is the (npts + 1)/2 sample, index is (npts + 1)/2 - 1
        stE_trim_data = stE_trim[0].data
        stZ_trim_data = stZ_trim[0].data
        
#         print(stN_trim[0].stats.starttime)
#         print(stN_trim[0].stats.endtime)
#         print(stN_trim[0].stats.npts) # Middle sample is the (npts + 1)/2 sample, index is (npts + 1)/2 - 1
#         print(len(stN_trim_data))
#         stN_trim[0].plot()

        npts = stN_trim[0].stats.npts
#         print(npts)
        arrival_idx = int((npts + 1)/2 - 1)
        
        pick_N = stN_trim_data[arrival_idx]
        pick_E = stE_trim_data[arrival_idx]   
        pick_Z = stZ_trim_data[arrival_idx]
        
#         print(pick_N)

        stN_norm = stN_trim_data - pick_N
        stE_norm = stE_trim_data - pick_E
        stZ_norm = stZ_trim_data - pick_Z    
        
        stN_zeroed = stN_norm
        stN_zeroed[0:128] = 0 # Remember that the stop index is excluded
        
        stE_zeroed = stE_norm
        stE_zeroed[0:128] = 0 
        
        stZ_zeroed = stZ_norm
        stZ_zeroed[0:128] = 0 
        
        ### Combine N, E, and Z components into one array ###
        
        comb_data = np.append(stN_zeroed, stE_zeroed)
        comb_data = np.append(comb_data, stZ_zeroed) # Order: N, E, Z
        
#         print(comb_data.shape)
        
        # N: indices 0 through 255 pick at index 128)
        # E: indices 256 through 511 (pick at index 384)
        # Z: indices 512 through 767 (pick at index 640)
        
#         plt.plot(comb_data) # Checking to make sure everything lines up
#         plt.xlim(635,645)
#         plt.ylim(-0.005, 0.005)
# #         plt.ylim(-0.2, 0.2)
#         plt.axvline(640)

        ### Adding new data to an array - each row = new station ### 
    
        data_list.append(comb_data) # Add clean data instead
        
        ### Add magnitude to list
        
        rupt_list.append(str(rupt))
        sta_list.append(str(sta))
        mag_list.append(str(mag))
# Out:
# Rupture newfault.000009 (10/3300)
# Rupture newfault.000019 (20/3300)
# Rupture newfault.000029 (30/3300)
# Rupture newfault.000039 (40/3300)
# Rupture newfault.000049 (50/3300)
# Rupture newfault.000059 (60/3300)
# Rupture newfault.000069 (70/3300)
# Rupture newfault.000079 (80/3300)
# Rupture newfault.000089 (90/3300)
# Rupture newfault.000099 (100/3300)
# Rupture newfault.000109 (110/3300)
# Rupture newfault.000119 (120/3300)
# Rupture newfault.000129 (130/3300)
# Rupture newfault.000139 (140/3300)
# Rupture newfault.000149 (150/3300)
# Rupture newfault.000159 (160/3300)
# Rupture newfault.000169 (170/3300)
# Rupture newfault.000179 (180/3300)
# Rupture newfault.000189 (190/3300)
# Rupture newfault.000199 (200/3300)
# Rupture newfault.000209 (210/3300)
# Rupture newfault.000219 (220/3300)
# Rupture newfault.000229 (230/3300)
# Rupture newfault.000239 (240/3300)
# Rupture newfault.000249 (250/3300)
# Rupture newfault.000259 (260/3300)
# Rupture newfault.000269 (270/3300)
# Rupture newfault.000279 (280/3300)
# Rupture newfault.000289 (290/3300)
# Rupture newfault.000299 (300/3300)
# Rupture newfault.000309 (310/3300)
# Rupture newfault.000319 (320/3300)
# Rupture newfault.000329 (330/3300)
# Rupture newfault.000339 (340/3300)
# Rupture newfault.000349 (350/3300)
# Rupture newfault.000359 (360/3300)
# Rupture newfault.000369 (370/3300)
# Rupture newfault.000379 (380/3300)
# Rupture newfault.000389 (390/3300)
# Rupture newfault.000399 (400/3300)
# Rupture newfault.000409 (410/3300)
# Rupture newfault.000419 (420/3300)
# Rupture newfault.000429 (430/3300)
# Rupture newfault.000439 (440/3300)
# Rupture newfault.000449 (450/3300)
# Rupture newfault.000459 (460/3300)
# Rupture newfault.000469 (470/3300)
# Rupture newfault.000479 (480/3300)
# Rupture newfault.000489 (490/3300)
# Rupture newfault.000499 (500/3300)
# Rupture newfault.000509 (510/3300)
# Rupture newfault.000519 (520/3300)
# Rupture newfault.000529 (530/3300)
# Rupture newfault.000539 (540/3300)
# Rupture newfault.000549 (550/3300)
# Rupture newfault.000559 (560/3300)
# Rupture newfault.000569 (570/3300)
# Rupture newfault.000579 (580/3300)
# Rupture newfault.000589 (590/3300)
# Rupture newfault.000599 (600/3300)
# Rupture newfault.000609 (610/3300)
# Rupture newfault.000619 (620/3300)
# Rupture newfault.000629 (630/3300)
# Rupture newfault.000639 (640/3300)
# Rupture newfault.000649 (650/3300)
# Rupture newfault.000659 (660/3300)
# Rupture newfault.000669 (670/3300)
# Rupture newfault.000679 (680/3300)
# Rupture newfault.000689 (690/3300)
# Rupture newfault.000699 (700/3300)
# Rupture newfault.000709 (710/3300)
# Rupture newfault.000719 (720/3300)
# Rupture newfault.000729 (730/3300)
# Rupture newfault.000739 (740/3300)
# Rupture newfault.000749 (750/3300)
# Rupture newfault.000759 (760/3300)
# Rupture newfault.000769 (770/3300)
# Rupture newfault.000779 (780/3300)
# Rupture newfault.000789 (790/3300)
# Rupture newfault.000799 (800/3300)
# Rupture newfault.000809 (810/3300)
# Rupture newfault.000819 (820/3300)
# Rupture newfault.000829 (830/3300)
# Rupture newfault.000839 (840/3300)
# Rupture newfault.000849 (850/3300)
# Rupture newfault.000859 (860/3300)
# Rupture newfault.000869 (870/3300)
# Rupture newfault.000879 (880/3300)
# Rupture newfault.000889 (890/3300)
# Rupture newfault.000899 (900/3300)
# Rupture newfault.000909 (910/3300)
# Rupture newfault.000919 (920/3300)
# Rupture newfault.000929 (930/3300)
# Rupture newfault.000939 (940/3300)
# Rupture newfault.000949 (950/3300)
# Rupture newfault.000959 (960/3300)
# Rupture newfault.000969 (970/3300)
# Rupture newfault.000979 (980/3300)
# Rupture newfault.000989 (990/3300)
# Rupture newfault.000999 (1000/3300)
# Rupture newfault.001009 (1010/3300)
# Rupture newfault.001019 (1020/3300)
# Rupture newfault.001029 (1030/3300)
# Rupture newfault.001039 (1040/3300)
# Rupture newfault.001049 (1050/3300)
# Rupture newfault.001059 (1060/3300)
# Rupture newfault.001069 (1070/3300)
# Rupture newfault.001079 (1080/3300)
# Rupture newfault.001089 (1090/3300)
# Rupture newfault.001099 (1100/3300)
# Rupture newfault.001109 (1110/3300)
# Rupture newfault.001119 (1120/3300)
# Rupture newfault.001129 (1130/3300)
# Rupture newfault.001139 (1140/3300)
# Rupture newfault.001149 (1150/3300)
# Rupture newfault.001159 (1160/3300)
# Rupture newfault.001169 (1170/3300)
# Rupture newfault.001179 (1180/3300)
# Rupture newfault.001189 (1190/3300)
# Rupture newfault.001199 (1200/3300)
# Rupture newfault.001209 (1210/3300)
# Rupture newfault.001219 (1220/3300)
# Rupture newfault.001229 (1230/3300)
# Rupture newfault.001239 (1240/3300)
# Rupture newfault.001249 (1250/3300)
# Rupture newfault.001259 (1260/3300)
# Rupture newfault.001269 (1270/3300)
# Rupture newfault.001279 (1280/3300)
# Rupture newfault.001289 (1290/3300)
# Rupture newfault.001299 (1300/3300)
# Rupture newfault.001309 (1310/3300)
# Rupture newfault.001319 (1320/3300)
# Rupture newfault.001329 (1330/3300)
# Rupture newfault.001339 (1340/3300)
# Rupture newfault.001349 (1350/3300)
# Rupture newfault.001359 (1360/3300)
# Rupture newfault.001369 (1370/3300)
# Rupture newfault.001379 (1380/3300)
# Rupture newfault.001389 (1390/3300)
# Rupture newfault.001399 (1400/3300)
# Rupture newfault.001409 (1410/3300)
# Rupture newfault.001419 (1420/3300)
# Rupture newfault.001429 (1430/3300)
# Rupture newfault.001439 (1440/3300)
# Rupture newfault.001449 (1450/3300)
# Rupture newfault.001459 (1460/3300)
# Rupture newfault.001469 (1470/3300)
# Rupture newfault.001479 (1480/3300)
# Rupture newfault.001489 (1490/3300)
# Rupture newfault.001499 (1500/3300)
# Rupture newfault.001509 (1510/3300)
# Rupture newfault.001519 (1520/3300)
# Rupture newfault.001529 (1530/3300)
# Rupture newfault.001539 (1540/3300)
# Rupture newfault.001549 (1550/3300)
# Rupture newfault.001559 (1560/3300)
# Rupture newfault.001569 (1570/3300)
# Rupture newfault.001579 (1580/3300)
# Rupture newfault.001589 (1590/3300)
# Rupture newfault.001599 (1600/3300)
# Rupture newfault.001609 (1610/3300)
# Rupture newfault.001619 (1620/3300)
# Rupture newfault.001629 (1630/3300)
# Rupture newfault.001639 (1640/3300)
# Rupture newfault.001649 (1650/3300)
# Rupture newfault.001659 (1660/3300)
# Rupture newfault.001669 (1670/3300)
# Rupture newfault.001679 (1680/3300)
# Rupture newfault.001689 (1690/3300)
# Rupture newfault.001699 (1700/3300)
# Rupture newfault.001709 (1710/3300)
# Rupture newfault.001719 (1720/3300)
# Rupture newfault.001729 (1730/3300)
# Rupture newfault.001739 (1740/3300)
# Rupture newfault.001749 (1750/3300)
# Rupture newfault.001759 (1760/3300)
# Rupture newfault.001769 (1770/3300)
# Rupture newfault.001779 (1780/3300)
# Rupture newfault.001789 (1790/3300)
# Rupture newfault.001799 (1800/3300)
# Rupture newfault.001809 (1810/3300)
# Rupture newfault.001819 (1820/3300)
# Rupture newfault.001829 (1830/3300)
# Rupture newfault.001839 (1840/3300)
# Rupture newfault.001849 (1850/3300)
# Rupture newfault.001859 (1860/3300)
# Rupture newfault.001869 (1870/3300)
# Rupture newfault.001879 (1880/3300)
# Rupture newfault.001889 (1890/3300)
# Rupture newfault.001899 (1900/3300)
# Rupture newfault.001909 (1910/3300)
# Rupture newfault.001919 (1920/3300)
# Rupture newfault.001929 (1930/3300)
# Rupture newfault.001939 (1940/3300)
# Rupture newfault.001949 (1950/3300)
# Rupture newfault.001959 (1960/3300)
# Rupture newfault.001969 (1970/3300)
# Rupture newfault.001979 (1980/3300)
# Rupture newfault.001989 (1990/3300)
# Rupture newfault.001999 (2000/3300)
# Rupture newfault.002009 (2010/3300)
# Rupture newfault.002019 (2020/3300)
# Rupture newfault.002029 (2030/3300)
# Rupture newfault.002039 (2040/3300)
# Rupture newfault.002049 (2050/3300)
# Rupture newfault.002059 (2060/3300)
# Rupture newfault.002069 (2070/3300)
# Rupture newfault.002079 (2080/3300)
# Rupture newfault.002089 (2090/3300)
# Rupture newfault.002099 (2100/3300)
# Rupture newfault.002109 (2110/3300)
# Rupture newfault.002119 (2120/3300)
# Rupture newfault.002129 (2130/3300)
# Rupture newfault.002139 (2140/3300)
# Rupture newfault.002149 (2150/3300)
# Rupture newfault.002159 (2160/3300)
# Rupture newfault.002169 (2170/3300)
# Rupture newfault.002179 (2180/3300)
# Rupture newfault.002189 (2190/3300)
# Rupture newfault.002199 (2200/3300)
# Rupture newfault.002209 (2210/3300)
# Rupture newfault.002219 (2220/3300)
# Rupture newfault.002229 (2230/3300)
# Rupture newfault.002239 (2240/3300)
# Rupture newfault.002249 (2250/3300)
# Rupture newfault.002259 (2260/3300)
# Rupture newfault.002269 (2270/3300)
# Rupture newfault.002279 (2280/3300)
# Rupture newfault.002289 (2290/3300)
# Rupture newfault.002299 (2300/3300)
# Rupture newfault.002309 (2310/3300)
# Rupture newfault.002319 (2320/3300)
# Rupture newfault.002329 (2330/3300)
# Rupture newfault.002339 (2340/3300)
# Rupture newfault.002349 (2350/3300)
# Rupture newfault.002359 (2360/3300)
# Rupture newfault.002369 (2370/3300)
# Rupture newfault.002379 (2380/3300)
# Rupture newfault.002389 (2390/3300)
# Rupture newfault.002399 (2400/3300)
# Rupture newfault.002409 (2410/3300)
# Rupture newfault.002419 (2420/3300)
# Rupture newfault.002429 (2430/3300)
# Rupture newfault.002439 (2440/3300)
# Rupture newfault.002449 (2450/3300)
# Rupture newfault.002459 (2460/3300)
# Rupture newfault.002469 (2470/3300)
# Rupture newfault.002479 (2480/3300)
# Rupture newfault.002489 (2490/3300)
# Rupture newfault.002499 (2500/3300)
# Rupture newfault.002509 (2510/3300)
# Rupture newfault.002519 (2520/3300)
# Rupture newfault.002529 (2530/3300)
# Rupture newfault.002539 (2540/3300)
# Rupture newfault.002549 (2550/3300)
# Rupture newfault.002559 (2560/3300)
# Rupture newfault.002569 (2570/3300)
# Rupture newfault.002579 (2580/3300)
# Rupture newfault.002589 (2590/3300)
# Rupture newfault.002599 (2600/3300)
# Rupture newfault.002609 (2610/3300)
# Rupture newfault.002619 (2620/3300)
# Rupture newfault.002629 (2630/3300)
# Rupture newfault.002639 (2640/3300)
# Rupture newfault.002649 (2650/3300)
# Rupture newfault.002659 (2660/3300)
# Rupture newfault.002669 (2670/3300)
# Rupture newfault.002679 (2680/3300)
# Rupture newfault.002689 (2690/3300)
# Rupture newfault.002699 (2700/3300)
# Rupture newfault.002709 (2710/3300)
# Rupture newfault.002719 (2720/3300)
# Rupture newfault.002729 (2730/3300)
# Rupture newfault.002739 (2740/3300)
# Rupture newfault.002749 (2750/3300)
# Rupture newfault.002759 (2760/3300)
# Rupture newfault.002769 (2770/3300)
# Rupture newfault.002779 (2780/3300)
# Rupture newfault.002789 (2790/3300)
# Rupture newfault.002799 (2800/3300)
# Rupture newfault.002809 (2810/3300)
# Rupture newfault.002819 (2820/3300)
# Rupture newfault.002829 (2830/3300)
# Rupture newfault.002839 (2840/3300)
# Rupture newfault.002849 (2850/3300)
# Rupture newfault.002859 (2860/3300)
# Rupture newfault.002869 (2870/3300)
# Rupture newfault.002879 (2880/3300)
# Rupture newfault.002889 (2890/3300)
# Rupture newfault.002899 (2900/3300)
# Rupture newfault.002909 (2910/3300)
# Rupture newfault.002919 (2920/3300)
# Rupture newfault.002929 (2930/3300)
# Rupture newfault.002939 (2940/3300)
# Rupture newfault.002949 (2950/3300)
# Rupture newfault.002959 (2960/3300)
# Rupture newfault.002969 (2970/3300)
# Rupture newfault.002979 (2980/3300)
# Rupture newfault.002989 (2990/3300)
# Rupture newfault.002999 (3000/3300)
# Rupture newfault.003009 (3010/3300)
# Rupture newfault.003019 (3020/3300)
# Rupture newfault.003029 (3030/3300)
# Rupture newfault.003039 (3040/3300)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 33
#      31         stN = read(fq_dir + 'output/waveforms/' + rupt + '/' + sta + '.LYN.sac')
#      32         stE = read(fq_dir + 'output/waveforms/' + rupt + '/' + sta + '.LYE.sac')
# ---> 33         stZ = read(fq_dir + 'output/waveforms/' + rupt + '/' + sta + '.LYZ.sac')
#      35 #         print(stN[0].stats.starttime)
#      36
#      37 #         stN.plot()
#      39         N_data = stN[0].data
#
# File ~/anaconda3/lib/python3.8/site-packages/decorator.py:231, in decorate.<locals>.fun(*args, **kw)
#     229 if not kwsyntax:
#     230     args, kw = fix(args, kw, sig)
# --> 231 return caller(func, *(extras + args), **kw)
#
# File ~/anaconda3/lib/python3.8/site-packages/obspy/core/util/decorator.py:297, in map_example_filename.<locals>._map_example_filename(func, *args, **kwargs)
#     295                 except IOError:
#     296                     pass
# --> 297 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.8/site-packages/obspy/core/stream.py:208, in read(pathname_or_url, format, headonly, starttime, endtime, nearest_sample, dtype, apply_calib, check_compression, **kwargs)
#     206     st = _create_example_stream(headonly=headonly)
#     207 else:
# --> 208     st = _generic_reader(pathname_or_url, _read, **kwargs)
#     210 if len(st) == 0:
#     211     # try to give more specific information why the stream is empty
#     212     if has_magic(pathname_or_url) and not glob(pathname_or_url):
#
# File ~/anaconda3/lib/python3.8/site-packages/obspy/core/util/base.py:656, in _generic_reader(pathname_or_url, callback_func, **kwargs)
#     654         raise Exception("No file matching file pattern: %s" % pathname)
#     655     elif not glob.has_magic(pathname) and not Path(pathname).is_file():
# --> 656         raise IOError(2, "No such file or directory", pathname)
#     658 generic = callback_func(pathnames[0], **kwargs)
#     659 if len(pathnames) > 1:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/hdd/rc_fq/fall24/newfault/output/waveforms/newfault.003043/P592.LYZ.sac'

# %%
data_array = np.array(data_list)
print('Data array shape:')
print(data_array.shape) # Arrivals at samples 128, 384, 640
# print(data_array[0])

rupt_array = np.array(rupt_list)
# print(rupt_array.shape)

sta_array = np.array(sta_list)
# print(sta_array.shape)

mag_array = np.array(mag_list)
# print(mag_array.shape)

info_array = np.column_stack((rupt_array, sta_array, mag_array))
print('Info array shape:')
print(info_array.shape)
print(info_array[-1])
# Out:
# Data array shape:
# (845964,)
# Info array shape:
# (845964, 3)
# ['newfault.003043' 'P570' '4.3148']
# /tmp/ipykernel_982416/4044905267.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   data_array = np.array(data_list)

# %%
h5f = h5py.File('/hdd/rc_fq/fall24/' + project_name + '_fq_wvfm_data_formatted.hdf5', 'w')
h5f.create_dataset('data', data = data_array)
h5f.close()

np.save('/hdd/rc_fq/fall24/' + project_name + '_fq_wvfm_info.npy', info_array)
