# %%
# Issue with the above is that the times aren't aligned anymore for the PGD timeseries because everything is shuffled to make the test data
# Think instead should go from the original data so the timing matches, and have moving 128 second windows (shift 1 sec each time?) for the M7+ data
# Start with M7.7+ to test?

# %%
from obspy import read, Stream, UTCDateTime
import numpy as np
from mudpy.hfsims import windowed_gaussian, apply_spectrum
from mudpy.forward import gnss_psd
import matplotlib.pyplot as plt
import h5py
from glob import glob

# %%
project_name = 'newfault'
GF_list = 'rc_gflist.gflist' # Station file used in fq gen code
vel_mod = 'mojave'
stas_name = GF_list.split('.')[0]
fq_dir = '/hdd/rc_fq/fall24/' + project_name + '/'
arrival_save_dir = '/hdd/rc_fq/fall24/' + project_name + '_fq_parrivals/'

all_ruptures = np.load('/hdd/rc_fq/fall24/' + project_name + '_ruptures.npy')
extra_second_rupts = ['newfault.000474', 'newfault.001647', 'newfault.001745', 'newfault.002078', 'newfault.002165', 'newfault.002607', 'newfault.002911', 'newfault.003012']

stas = np.load('/hdd/rc_fq/fall24/' + stas_name + '_station_names.npy')
test_stas = ['P595', 'P594', 'CCCC']
# print(stas)

# %%
# mags_765 = []
# rupts_765 = []

# for idx in range(len(all_ruptures)):
    
#     rupt = all_ruptures[idx]
    
#     log = glob(fq_dir + 'output/ruptures/' + rupt + '.log')
#     log = open(log[0],'r')
#     line = log.readlines()
    
#     mag = str(line[15][21:27])
    
#     if float(mag) >= 7.65:
# #         print(mag)
# #         print(rupt)
#         rupts_765.append(rupt)
        
# print(rupts_765)

rupts_6 = []

for idx in range(len(all_ruptures)):
    
    rupt = all_ruptures[idx]
    
    log = glob(fq_dir + 'output/ruptures/' + rupt + '.log')
    log = open(log[0],'r')
    line = log.readlines()
    
    mag = str(line[15][21:27])
    
    if float(mag) >= 6:
#         print(mag)
#         print(rupt)
        rupts_6.append(rupt)
        
# print(rupts_6)

# %%
# Reformatting FQ data so that they start at the origin time and go for 128 seconds

len_new_data_array = 0

# for idx in range(len(rupts_765)):
#     rupt = rupts_765[idx]
#     q = np.where(results[:,0] == rupt)[0]
#     stas_in_testing = results[q,1]
# #     print(rupt)
# #     print(stas_in_testing)
# #     print(len(stas_in_testing))
#     len_new_data_array += len(stas_in_testing)

# ruptures = rupts_765

for idx in range(len(rupts_6)):
    rupt = rupts_6[idx]
    q = np.where(results[:,0] == rupt)[0]
    stas_in_testing = results[q,1]
#     print(rupt)
#     print(stas_in_testing)
#     print(len(stas_in_testing))
    len_new_data_array += len(stas_in_testing)    

ruptures = rupts_6

print(len_new_data_array)

origin_time = UTCDateTime('2019-07-06T03:19:53.040000Z')
print(origin_time)

new_data_array = np.zeros((len_new_data_array, 128*3))
print(new_data_array.shape)

mag_list = []
sta_list = []
rupt_list = []
arr_idx_list = []

# data_list = []

counter = 0
new_array_counter = -1

for idx in range(len(ruptures)):
    
    rupt = ruptures[idx]
    q = np.where(results[:,0] == rupt)[0]
    stas_in_testing = results[q,1]
    
    counter += 1
    if counter % 10 == 0:
        print('Rupture ' + rupt + ' (' + str(counter) + '/' + str(len(ruptures)) + ')')
    
    log = glob(fq_dir + 'output/ruptures/' + rupt + '.log')
    log = open(log[0],'r')
    line = log.readlines()
    
    mag = str(line[15][21:27])
#     print(mag)
    
#     print('Origin time:')
#     print(origin_time)
    
    for idx2 in range(len(stas_in_testing)):
        
        new_array_counter += 1
        
        sta = stas_in_testing[idx2]
        
#         print(sta)
        arrivals = np.genfromtxt(arrival_save_dir + stas_name + '_arrival_times_' + rupt + '.csv', dtype = 'U')
#         print(arrivals)
            
        # Read in data 
        
        stN = read(fq_dir + 'output/waveforms/' + rupt + '/' + sta + '.LYN.sac') 
        stE = read(fq_dir + 'output/waveforms/' + rupt + '/' + sta + '.LYE.sac') 
        stZ = read(fq_dir + 'output/waveforms/' + rupt + '/' + sta + '.LYZ.sac') 
        
        # Get arrival time
        
        stas_arrival = arrivals[:,1] # Station list from arrivals file
        i = np.where(stas_arrival == sta)[0]
        arrival = arrivals[i,2][0]
        arr_time = UTCDateTime(arrival)
#         print(arrival)

        ### Trim around the origin time
        
        starttime = origin_time
        endtime = starttime + 127
        
        stN_trim = stN.trim(starttime, endtime)
        stE_trim = stE.trim(starttime, endtime)
        stZ_trim = stZ.trim(starttime, endtime)
        
#         print(stN_trim[0].stats.npts)
        
        stN_trim_data = stN_trim[0].data
        stE_trim_data = stE_trim[0].data
        stZ_trim_data = stZ_trim[0].data
        
#         print(stN_trim_data.shape)
        
#         print(arr_time)
#         print(origin_time)
        arrival_idx = int(round(arr_time - starttime))
#         print(arrival_idx)
        
        ### Combine N, E, and Z components into one array ###
        
        comb_data = np.append(stN_trim_data, stE_trim_data)
        comb_data = np.append(comb_data, stZ_trim_data) # Order: N, E, Z
        
        new_data_array[new_array_counter] = comb_data
        
#         plt.plot(comb_data) # Checking to make sure everything lines up
#         plt.show();
        
        ### Add magnitude to list
        
        rupt_list.append(str(rupt))
        sta_list.append(str(sta))
        mag_list.append(str(mag))
        arr_idx_list.append(str(arrival_idx))
# Out:
# 20683
# 2019-07-06T03:19:53.040000Z
# (20683, 384)
# Rupture newfault.000009 (10/1491)
# Rupture newfault.000019 (20/1491)
# Rupture newfault.000029 (30/1491)
# Rupture newfault.000039 (40/1491)
# Rupture newfault.000049 (50/1491)
# Rupture newfault.000059 (60/1491)
# Rupture newfault.000069 (70/1491)
# Rupture newfault.000079 (80/1491)
# Rupture newfault.000089 (90/1491)
# Rupture newfault.000099 (100/1491)
# Rupture newfault.000109 (110/1491)
# Rupture newfault.000119 (120/1491)
# Rupture newfault.000129 (130/1491)
# Rupture newfault.000139 (140/1491)
# Rupture newfault.000149 (150/1491)
# Rupture newfault.000159 (160/1491)
# Rupture newfault.000169 (170/1491)
# Rupture newfault.000179 (180/1491)
# Rupture newfault.000189 (190/1491)
# Rupture newfault.000199 (200/1491)
# Rupture newfault.000209 (210/1491)
# Rupture newfault.000219 (220/1491)
# Rupture newfault.000229 (230/1491)
# Rupture newfault.000239 (240/1491)
# Rupture newfault.000249 (250/1491)
# Rupture newfault.000259 (260/1491)
# Rupture newfault.000269 (270/1491)
# Rupture newfault.000279 (280/1491)
# Rupture newfault.000289 (290/1491)
# Rupture newfault.000299 (300/1491)
# Rupture newfault.000309 (310/1491)
# Rupture newfault.000319 (320/1491)
# Rupture newfault.000329 (330/1491)
# Rupture newfault.000339 (340/1491)
# Rupture newfault.000349 (350/1491)
# Rupture newfault.000359 (360/1491)
# Rupture newfault.000369 (370/1491)
# Rupture newfault.000379 (380/1491)
# Rupture newfault.000389 (390/1491)
# Rupture newfault.000399 (400/1491)
# Rupture newfault.000409 (410/1491)
# Rupture newfault.000419 (420/1491)
# Rupture newfault.000429 (430/1491)
# Rupture newfault.000439 (440/1491)
# Rupture newfault.000449 (450/1491)
# Rupture newfault.000459 (460/1491)
# Rupture newfault.000469 (470/1491)
# Rupture newfault.000479 (480/1491)
# Rupture newfault.000489 (490/1491)
# Rupture newfault.000499 (500/1491)
# Rupture newfault.000509 (510/1491)
# Rupture newfault.000519 (520/1491)
# Rupture newfault.000529 (530/1491)
# Rupture newfault.000539 (540/1491)
# Rupture newfault.000549 (550/1491)
# Rupture newfault.000559 (560/1491)
# Rupture newfault.000569 (570/1491)
# Rupture newfault.000579 (580/1491)
# Rupture newfault.000589 (590/1491)
# Rupture newfault.000599 (600/1491)
# Rupture newfault.000609 (610/1491)
# Rupture newfault.000619 (620/1491)
# Rupture newfault.000629 (630/1491)
# Rupture newfault.000639 (640/1491)
# Rupture newfault.000649 (650/1491)
# Rupture newfault.000659 (660/1491)
# Rupture newfault.000669 (670/1491)
# Rupture newfault.000679 (680/1491)
# Rupture newfault.000689 (690/1491)
# Rupture newfault.000699 (700/1491)
# Rupture newfault.000709 (710/1491)
# Rupture newfault.000719 (720/1491)
# Rupture newfault.000729 (730/1491)
# Rupture newfault.000739 (740/1491)
# Rupture newfault.000749 (750/1491)
# Rupture newfault.000759 (760/1491)
# Rupture newfault.000769 (770/1491)
# Rupture newfault.000779 (780/1491)
# Rupture newfault.000789 (790/1491)
# Rupture newfault.000799 (800/1491)
# Rupture newfault.000809 (810/1491)
# Rupture newfault.000819 (820/1491)
# Rupture newfault.000829 (830/1491)
# Rupture newfault.000839 (840/1491)
# Rupture newfault.000849 (850/1491)
# Rupture newfault.000859 (860/1491)
# Rupture newfault.000869 (870/1491)
# Rupture newfault.000879 (880/1491)
# Rupture newfault.000889 (890/1491)
# Rupture newfault.000899 (900/1491)
# Rupture newfault.000909 (910/1491)
# Rupture newfault.000919 (920/1491)
# Rupture newfault.000929 (930/1491)
# Rupture newfault.000939 (940/1491)
# Rupture newfault.000949 (950/1491)
# Rupture newfault.000959 (960/1491)
# Rupture newfault.000969 (970/1491)
# Rupture newfault.000979 (980/1491)
# Rupture newfault.000989 (990/1491)
# Rupture newfault.000999 (1000/1491)
# Rupture newfault.001009 (1010/1491)
# Rupture newfault.001019 (1020/1491)
# Rupture newfault.001029 (1030/1491)
# Rupture newfault.001039 (1040/1491)
# Rupture newfault.001049 (1050/1491)
# Rupture newfault.001059 (1060/1491)
# Rupture newfault.001069 (1070/1491)
# Rupture newfault.001079 (1080/1491)
# Rupture newfault.001089 (1090/1491)
# Rupture newfault.001099 (1100/1491)
# Rupture newfault.001109 (1110/1491)
# Rupture newfault.001119 (1120/1491)
# Rupture newfault.001129 (1130/1491)
# Rupture newfault.001141 (1140/1491)
# Rupture newfault.001151 (1150/1491)
# Rupture newfault.001161 (1160/1491)
# Rupture newfault.001172 (1170/1491)
# Rupture newfault.001182 (1180/1491)
# Rupture newfault.001193 (1190/1491)
# Rupture newfault.001204 (1200/1491)
# Rupture newfault.001216 (1210/1491)
# Rupture newfault.001228 (1220/1491)
# Rupture newfault.001239 (1230/1491)
# Rupture newfault.001249 (1240/1491)
# Rupture newfault.001259 (1250/1491)
# Rupture newfault.001270 (1260/1491)
# Rupture newfault.001281 (1270/1491)
# Rupture newfault.001292 (1280/1491)
# Rupture newfault.001302 (1290/1491)
# Rupture newfault.001312 (1300/1491)
# Rupture newfault.001326 (1310/1491)
# Rupture newfault.001341 (1320/1491)
# Rupture newfault.001356 (1330/1491)
# Rupture newfault.001369 (1340/1491)
# Rupture newfault.001383 (1350/1491)
# Rupture newfault.001396 (1360/1491)
# Rupture newfault.001414 (1370/1491)
# Rupture newfault.001430 (1380/1491)
# Rupture newfault.001449 (1390/1491)
# Rupture newfault.001470 (1400/1491)
# Rupture newfault.001482 (1410/1491)
# Rupture newfault.001503 (1420/1491)
# Rupture newfault.001524 (1430/1491)
# Rupture newfault.001549 (1440/1491)
# Rupture newfault.001576 (1450/1491)
# Rupture newfault.001613 (1460/1491)
# Rupture newfault.001646 (1470/1491)
# Rupture newfault.001685 (1480/1491)
# Rupture newfault.001776 (1490/1491)

# %%
new_data_array.shape
# Out:
# (20683, 384)

# %%
print(len(arr_idx_list))
# Out:
# 20683

# %%
print('New data array shape:')
print(new_data_array.shape) # Arrivals at samples 128, 384, 640
# print(data_array[0])

rupt_array = np.array(rupt_list)
# print(rupt_array.shape)

sta_array = np.array(sta_list)
# print(sta_array.shape)

mag_array = np.array(mag_list)
# print(mag_array.shape)

arridx_array = np.array(arr_idx_list)
# print(mag_array.shape)

info_array = np.column_stack((rupt_array, sta_array, mag_array, arridx_array))
print('Info array shape:')
print(info_array.shape)
print(info_array[-1])
# Out:
# New data array shape:
# (20683, 384)
# Info array shape:
# (20683, 4)
# ['newfault.001779' 'P581' '6.0685' '19']

# %%
h5f = h5py.File('/hdd/rc_fq/fall24/' + project_name + '_gfast_test_6.hdf5', 'w')
h5f.create_dataset('data', data = new_data_array)
h5f.close()

np.save('/hdd/rc_fq/fall24/' + project_name + '_gfast_test_6_info.npy', info_array)
