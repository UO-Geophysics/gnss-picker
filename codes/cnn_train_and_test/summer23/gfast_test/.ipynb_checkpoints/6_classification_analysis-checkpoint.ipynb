# %%
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
from obspy.geodetics import gps2dist_azimuth

path = '/home/sdybing/gnss-picker/cnn_models_outputs/newfault_fq_train/models/traindate_2024-10-01/data/'

data = np.load(path + '2024-10-16_gfast_bigger_fqtest_orig_data.npy')
metadata = np.load(path + 'pgd_bigger_test_metadata_w_hypdist_pgd_snrs.npy')
targets = np.load(path + '2024-10-16_gfast_bigger_fqtest_target.npy')
predictions = np.load(path + '2024-10-16_gfast_bigger_fqtest_predictions.npy')

num_fqtest = len(predictions)
thresholds = np.arange(0, 1.005, 0.005)
test_thresholds = [0, 0.005]

# %%
accuracies = []
precisions = []
recalls = []
F1s = []

for ind in range(len(thresholds)):
    
    threshold = np.round(thresholds[ind],3)
    
    print('-------------------------------------------------------------')
    print('Threshold: ' + str(threshold))
    
    iterate = np.arange(0,num_fqtest,1)
    
    # Convert the prediction arrays to 1s and 0s if the prediction Gaussian exceeded the threshold or not
        
    pred_binary = np.zeros(len(predictions)) # Initialize the array with all zeros
    for k in iterate:
#         plt.plot(fqtest_predictions[k]) # The output "Gaussian" or straight line prediction
#         plt.ylim(0,1)
#         plt.show()
        i = np.where(predictions[k] >= threshold)[0]
        if len(i) == 0: 
            pred_binary[k] = 0
        elif len(i) > 0: # If anywhere in the prediction the Gaussian exceeds the threadshold, add a 1 to the pred_binary array for this prediction
            pred_binary[k] = 1
#     print('Predictions: ')
#     print(pred_binary) 
    
    # Convert the target arrays to 1s and 0s if the Gaussian exceeded the threshold or not (signal or noise)
    
    targ_binary = np.zeros(len(targets))
    for k in iterate:
        i = np.where(targets[k] > 0)[0]
        if len(i) == 0:
            targ_binary[k] = 0
        elif len(i) > 0:
            targ_binary[k] = 1
#     print('Targets: ')
#     print(targ_binary)
    
    # Calculating the accuracy, precision, recall, and F1
    
    num_preds = num_fqtest # Total number of predictions
    correct_preds = []
    wrong_preds = []
    true_pos = []
    true_neg = []
    false_pos = []
    false_neg = []
    
    for i in iterate:
        
        pred = pred_binary[i]
        targ = targ_binary[i]
        
        if pred == targ: # Add one to list of correct predictions if matching
            correct_preds.append(1)
            
            if pred == 1 and targ == 1: # True positive: there is an earthquake, and the model found it
                true_pos.append(1)
            elif pred == 0 and targ == 0: # True negative: there isn't an earthquake, and the model found just noise
                true_neg.append(1)
            
        elif pred != targ: # Add ones to list of incorrect predictions if not matching
            wrong_preds.append(1)
            
            if pred == 1 and targ == 0: # False positive: there isn't an earthquake, and the model thought it found one
                false_pos.append(1)
            elif pred == 0 and targ == 1: # False negative: there is an earthquake, and the model missed it
                false_neg.append(1)
    
    num_correct_preds = len(correct_preds)
    num_wrong_preds = len(wrong_preds)
    num_true_pos = len(true_pos)
    num_true_neg = len(true_neg)
    num_false_pos = len(false_pos)
    num_false_neg = len(false_neg)
    
    # print('Threshold: ' + str(threshold))
    # print('Correct preds: ' + str(num_correct_preds))
    # print('Wrong preds: ' + str(num_wrong_preds))
    # print('True pos: ' + str(num_true_pos))
    # print('True neg: ' + str(num_true_neg))
    # print('False pos: ' + str(num_false_pos))
    # print('False neg: ' + str(num_false_neg))
    
    accuracy = num_correct_preds / num_preds
    accuracy_per = (num_correct_preds / num_preds) * 100
    print('Accuracy: ' + str(accuracy_per) + '%')
    
    if num_true_pos == 0  and num_false_pos == 0:
        precision = 0
    else:
        precision = num_true_pos / (num_true_pos + num_false_pos)
    
    if num_true_pos == 0 and num_false_neg == 0:
        recall = 0
    else:
        recall = num_true_pos / (num_true_pos + num_false_neg)
    
    if precision + recall == 0:
        F1 = 0
    else:
        F1 = 2 * ((precision * recall) / (precision + recall))
    
    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    F1s.append(F1)

# print('Accuracies')
# print(accuracies)
# print('Precisions')
# print(precisions)
# print('Recalls')
# print(recalls)
# print('F1s')
# print(F1s)
# Out:
# -------------------------------------------------------------
# Threshold: 0.0
# Accuracy: 100.0%
# -------------------------------------------------------------
# Threshold: 0.005
# Accuracy: 100.0%
# -------------------------------------------------------------
# Threshold: 0.01
# Accuracy: 100.0%
# -------------------------------------------------------------
# Threshold: 0.015
# Accuracy: 100.0%
# -------------------------------------------------------------
# Threshold: 0.02
# Accuracy: 100.0%
# -------------------------------------------------------------
# Threshold: 0.025
# Accuracy: 100.0%
# -------------------------------------------------------------
# Threshold: 0.03
# Accuracy: 99.41981337330175%
# -------------------------------------------------------------
# Threshold: 0.035
# Accuracy: 95.61475607987235%
# -------------------------------------------------------------
# Threshold: 0.04
# Accuracy: 90.60097664748827%
# -------------------------------------------------------------
# Threshold: 0.045
# Accuracy: 86.25924672436301%
# -------------------------------------------------------------
# Threshold: 0.05
# Accuracy: 82.4251800995987%
# -------------------------------------------------------------
# Threshold: 0.055
# Accuracy: 79.2341536527583%
# -------------------------------------------------------------
# Threshold: 0.06
# Accuracy: 76.45892762171832%
# -------------------------------------------------------------
# Threshold: 0.065
# Accuracy: 73.96896001547164%
# -------------------------------------------------------------
# Threshold: 0.07
# Accuracy: 71.89962771358121%
# -------------------------------------------------------------
# Threshold: 0.075
# Accuracy: 69.9705071798095%
# -------------------------------------------------------------
# Threshold: 0.08
# Accuracy: 68.2734612967171%
# -------------------------------------------------------------
# Threshold: 0.085
# Accuracy: 66.74080162452255%
# -------------------------------------------------------------
# Threshold: 0.09
# Accuracy: 65.22264661799545%
# -------------------------------------------------------------
# Threshold: 0.095
# Accuracy: 63.83503360247546%
# -------------------------------------------------------------
# Threshold: 0.1
# Accuracy: 62.47159502973456%
# -------------------------------------------------------------
# Threshold: 0.105
# Accuracy: 61.36440555045206%
# -------------------------------------------------------------
# Threshold: 0.11
# Accuracy: 60.199197408499735%
# -------------------------------------------------------------
# Threshold: 0.115
# Accuracy: 59.304743025673254%
# -------------------------------------------------------------
# Threshold: 0.12
# Accuracy: 58.42962819707006%
# -------------------------------------------------------------
# Threshold: 0.125
# Accuracy: 57.62703669680413%
# -------------------------------------------------------------
# Threshold: 0.13
# Accuracy: 56.925977856210416%
# -------------------------------------------------------------
# Threshold: 0.135
# Accuracy: 56.30711212106561%
# -------------------------------------------------------------
# Threshold: 0.14
# Accuracy: 55.6108881690277%
# -------------------------------------------------------------
# Threshold: 0.145
# Accuracy: 55.050041096552725%
# -------------------------------------------------------------
# Threshold: 0.15
# Accuracy: 54.51820335541265%
# -------------------------------------------------------------
# Threshold: 0.155
# Accuracy: 54.02504472271914%
# -------------------------------------------------------------
# Threshold: 0.16
# Accuracy: 53.556060532804715%
# -------------------------------------------------------------
# Threshold: 0.165
# Accuracy: 53.12092056278102%
# -------------------------------------------------------------
# Threshold: 0.17
# Accuracy: 52.7534690325388%
# -------------------------------------------------------------
# Threshold: 0.175
# Accuracy: 52.429531499298946%
# -------------------------------------------------------------
# Threshold: 0.18
# Accuracy: 52.187787071508005%
# -------------------------------------------------------------
# Threshold: 0.185
# Accuracy: 51.9025286467147%
# -------------------------------------------------------------
# Threshold: 0.19
# Accuracy: 51.7236377701494%
# -------------------------------------------------------------
# Threshold: 0.195
# Accuracy: 51.568921336363196%
# -------------------------------------------------------------
# Threshold: 0.2
# Accuracy: 51.40453512546536%
# -------------------------------------------------------------
# Threshold: 0.205
# Accuracy: 51.27399313445825%
# -------------------------------------------------------------
# Threshold: 0.21
# Accuracy: 51.143451143451145%
# -------------------------------------------------------------
# Threshold: 0.215
# Accuracy: 51.00807426388821%
# -------------------------------------------------------------
# Threshold: 0.22
# Accuracy: 50.921046269883476%
# -------------------------------------------------------------
# Threshold: 0.225
# Accuracy: 50.77599961320891%
# -------------------------------------------------------------
# Threshold: 0.23
# Accuracy: 50.65996228786926%
# -------------------------------------------------------------
# Threshold: 0.235
# Accuracy: 50.543924962529616%
# -------------------------------------------------------------
# Threshold: 0.24
# Accuracy: 50.45206207996906%
# -------------------------------------------------------------
# Threshold: 0.245
# Accuracy: 50.3601991974085%
# -------------------------------------------------------------
# Threshold: 0.25
# Accuracy: 50.25383164918049%
# -------------------------------------------------------------
# Threshold: 0.255
# Accuracy: 50.152298989508296%
# -------------------------------------------------------------
# Threshold: 0.26
# Accuracy: 50.06043610694773%
# -------------------------------------------------------------
# Threshold: 0.265
# Accuracy: 49.99758255572209%
# -------------------------------------------------------------
# Threshold: 0.27
# Accuracy: 49.915389450273175%
# -------------------------------------------------------------
# Threshold: 0.275
# Accuracy: 49.7945172363777%
# -------------------------------------------------------------
# Threshold: 0.28
# Accuracy: 49.74616835081952%
# -------------------------------------------------------------
# Threshold: 0.285
# Accuracy: 49.63496591403568%
# -------------------------------------------------------------
# Threshold: 0.29
# Accuracy: 49.5624425856984%
# -------------------------------------------------------------
# Threshold: 0.295
# Accuracy: 49.456075037470384%
# -------------------------------------------------------------
# Threshold: 0.3
# Accuracy: 49.41256104046802%
# -------------------------------------------------------------
# Threshold: 0.305
# Accuracy: 49.3303679350191%
# -------------------------------------------------------------
# Threshold: 0.31
# Accuracy: 49.23367016390272%
# -------------------------------------------------------------
# Threshold: 0.315
# Accuracy: 49.13697239278635%
# -------------------------------------------------------------
# Threshold: 0.32
# Accuracy: 49.054779287337425%
# -------------------------------------------------------------
# Threshold: 0.325
# Accuracy: 49.00643040177924%
# -------------------------------------------------------------
# Threshold: 0.33
# Accuracy: 48.900062853551226%
# -------------------------------------------------------------
# Threshold: 0.335
# Accuracy: 48.77919063965576%
# -------------------------------------------------------------
# Threshold: 0.34
# Accuracy: 48.69699753420684%
# -------------------------------------------------------------
# Threshold: 0.345
# Accuracy: 48.653483537204465%
# -------------------------------------------------------------
# Threshold: 0.35
# Accuracy: 48.56162065464391%
# -------------------------------------------------------------
# Threshold: 0.355
# Accuracy: 48.47459266063917%
# -------------------------------------------------------------
# Threshold: 0.36
# Accuracy: 48.39723444374607%
# -------------------------------------------------------------
# Threshold: 0.365
# Accuracy: 48.3005366726297%
# -------------------------------------------------------------
# Threshold: 0.37
# Accuracy: 48.218343567180774%
# -------------------------------------------------------------
# Threshold: 0.375
# Accuracy: 48.10714113039695%
# -------------------------------------------------------------
# Threshold: 0.38
# Accuracy: 48.024948024948024%
# -------------------------------------------------------------
# Threshold: 0.385
# Accuracy: 47.92341536527583%
# -------------------------------------------------------------
# Threshold: 0.39
# Accuracy: 47.855726925494366%
# -------------------------------------------------------------
# Threshold: 0.395
# Accuracy: 47.78320359715708%
# -------------------------------------------------------------
# Threshold: 0.4
# Accuracy: 47.73001982304308%
# -------------------------------------------------------------
# Threshold: 0.405
# Accuracy: 47.65266160614998%
# -------------------------------------------------------------
# Threshold: 0.41
# Accuracy: 47.59464294348015%
# -------------------------------------------------------------
# Threshold: 0.415
# Accuracy: 47.464100952473046%
# -------------------------------------------------------------
# Threshold: 0.42
# Accuracy: 47.40608228980322%
# -------------------------------------------------------------
# Threshold: 0.425
# Accuracy: 47.3480636271334%
# -------------------------------------------------------------
# Threshold: 0.43
# Accuracy: 47.28037518735193%
# -------------------------------------------------------------
# Threshold: 0.435
# Accuracy: 47.15950297345646%
# -------------------------------------------------------------
# Threshold: 0.44
# Accuracy: 47.077309868007546%
# -------------------------------------------------------------
# Threshold: 0.445
# Accuracy: 46.98544698544699%
# -------------------------------------------------------------
# Threshold: 0.45
# Accuracy: 46.86940966010734%
# -------------------------------------------------------------
# Threshold: 0.455
# Accuracy: 46.74370255765605%
# -------------------------------------------------------------
# Threshold: 0.46
# Accuracy: 46.627665232316396%
# -------------------------------------------------------------
# Threshold: 0.465
# Accuracy: 46.53580234975584%
# -------------------------------------------------------------
# Threshold: 0.47
# Accuracy: 46.45844413286274%
# -------------------------------------------------------------
# Threshold: 0.475
# Accuracy: 46.35691147319054%
# -------------------------------------------------------------
# Threshold: 0.48
# Accuracy: 46.2166997050718%
# -------------------------------------------------------------
# Threshold: 0.485
# Accuracy: 46.06681815984142%
# -------------------------------------------------------------
# Threshold: 0.49
# Accuracy: 45.979790165836675%
# -------------------------------------------------------------
# Threshold: 0.495
# Accuracy: 45.86858772905285%
# -------------------------------------------------------------
# Threshold: 0.5
# Accuracy: 45.76222018082483%
# -------------------------------------------------------------
# Threshold: 0.505
# Accuracy: 45.64134796692937%
# -------------------------------------------------------------
# Threshold: 0.51
# Accuracy: 45.52531064158971%
# -------------------------------------------------------------
# Threshold: 0.515
# Accuracy: 45.399603539138425%
# -------------------------------------------------------------
# Threshold: 0.52
# Accuracy: 45.28840110235459%
# -------------------------------------------------------------
# Threshold: 0.525
# Accuracy: 45.21587777401731%
# -------------------------------------------------------------
# Threshold: 0.53
# Accuracy: 45.10467533723347%
# -------------------------------------------------------------
# Threshold: 0.535
# Accuracy: 45.01281245467292%
# -------------------------------------------------------------
# Threshold: 0.54
# Accuracy: 44.87260068655418%
# -------------------------------------------------------------
# Threshold: 0.545
# Accuracy: 44.751728472658705%
# -------------------------------------------------------------
# Threshold: 0.55
# Accuracy: 44.5970120388725%
# -------------------------------------------------------------
# Threshold: 0.555
# Accuracy: 44.44713049364212%
# -------------------------------------------------------------
# Threshold: 0.56
# Accuracy: 44.30208383696756%
# -------------------------------------------------------------
# Threshold: 0.565
# Accuracy: 44.118358071846444%
# -------------------------------------------------------------
# Threshold: 0.57
# Accuracy: 43.953971860948606%
# -------------------------------------------------------------
# Threshold: 0.575
# Accuracy: 43.80409031571823%
# -------------------------------------------------------------
# Threshold: 0.58
# Accuracy: 43.62519943915293%
# -------------------------------------------------------------
# Threshold: 0.585
# Accuracy: 43.48015278247836%
# -------------------------------------------------------------
# Threshold: 0.59
# Accuracy: 43.34477590291544%
# -------------------------------------------------------------
# Threshold: 0.595
# Accuracy: 43.24324324324324%
# -------------------------------------------------------------
# Threshold: 0.6
# Accuracy: 43.10786636368032%
# -------------------------------------------------------------
# Threshold: 0.605
# Accuracy: 42.98215926122903%
# -------------------------------------------------------------
# Threshold: 0.61
# Accuracy: 42.80326838466373%
# -------------------------------------------------------------
# Threshold: 0.615
# Accuracy: 42.64371706232171%
# -------------------------------------------------------------
# Threshold: 0.62
# Accuracy: 42.489000628535514%
# -------------------------------------------------------------
# Threshold: 0.625
# Accuracy: 42.34878886041677%
# -------------------------------------------------------------
# Threshold: 0.63
# Accuracy: 42.22308175796548%
# -------------------------------------------------------------
# Threshold: 0.635
# Accuracy: 42.04419088140018%
# -------------------------------------------------------------
# Threshold: 0.64
# Accuracy: 41.865300004834886%
# -------------------------------------------------------------
# Threshold: 0.645
# Accuracy: 41.65739979693468%
# -------------------------------------------------------------
# Threshold: 0.65
# Accuracy: 41.49784847459266%
# -------------------------------------------------------------
# Threshold: 0.655
# Accuracy: 41.31895759802737%
# -------------------------------------------------------------
# Threshold: 0.66
# Accuracy: 41.11589227868298%
# -------------------------------------------------------------
# Threshold: 0.665
# Accuracy: 40.91766184789441%
# -------------------------------------------------------------
# Threshold: 0.67
# Accuracy: 40.71943141710583%
# -------------------------------------------------------------
# Threshold: 0.675
# Accuracy: 40.49702654353817%
# -------------------------------------------------------------
# Threshold: 0.68
# Accuracy: 40.3229705555287%
# -------------------------------------------------------------
# Threshold: 0.685
# Accuracy: 40.12474012474013%
# -------------------------------------------------------------
# Threshold: 0.69
# Accuracy: 39.92167480539573%
# -------------------------------------------------------------
# Threshold: 0.695
# Accuracy: 39.66059082338152%
# -------------------------------------------------------------
# Threshold: 0.7
# Accuracy: 39.44302083836968%
# -------------------------------------------------------------
# Threshold: 0.705
# Accuracy: 39.23028574191365%
# -------------------------------------------------------------
# Threshold: 0.71
# Accuracy: 38.998211091234346%
# -------------------------------------------------------------
# Threshold: 0.715
# Accuracy: 38.756466663443405%
# -------------------------------------------------------------
# Threshold: 0.72
# Accuracy: 38.44703379587101%
# -------------------------------------------------------------
# Threshold: 0.725
# Accuracy: 38.176280036745155%
# -------------------------------------------------------------
# Threshold: 0.73
# Accuracy: 37.87651694628439%
# -------------------------------------------------------------
# Threshold: 0.735
# Accuracy: 37.51390030459798%
# -------------------------------------------------------------
# Threshold: 0.74
# Accuracy: 37.23347676836049%
# -------------------------------------------------------------
# Threshold: 0.745
# Accuracy: 36.933713677899725%
# -------------------------------------------------------------
# Threshold: 0.75
# Accuracy: 36.57109703621331%
# -------------------------------------------------------------
# Threshold: 0.755
# Accuracy: 36.2084803945269%
# -------------------------------------------------------------
# Threshold: 0.76
# Accuracy: 35.81201953294977%
# -------------------------------------------------------------
# Threshold: 0.765
# Accuracy: 35.39138422859353%
# -------------------------------------------------------------
# Threshold: 0.77
# Accuracy: 34.95140937001402%
# -------------------------------------------------------------
# Threshold: 0.775
# Accuracy: 34.51626939999033%
# -------------------------------------------------------------
# Threshold: 0.78
# Accuracy: 34.08596431852246%
# -------------------------------------------------------------
# Threshold: 0.785
# Accuracy: 33.73301745394769%
# -------------------------------------------------------------
# Threshold: 0.79
# Accuracy: 33.259198375477446%
# -------------------------------------------------------------
# Threshold: 0.795
# Accuracy: 32.770874631339744%
# -------------------------------------------------------------
# Threshold: 0.8
# Accuracy: 32.28738577575787%
# -------------------------------------------------------------
# Threshold: 0.805
# Accuracy: 31.755548034617803%
# -------------------------------------------------------------
# Threshold: 0.81
# Accuracy: 31.189866073587%
# -------------------------------------------------------------
# Threshold: 0.815
# Accuracy: 30.56616544988638%
# -------------------------------------------------------------
# Threshold: 0.82
# Accuracy: 30.04883237441377%
# -------------------------------------------------------------
# Threshold: 0.825
# Accuracy: 29.347773533820043%
# -------------------------------------------------------------
# Threshold: 0.83
# Accuracy: 28.772421795677612%
# -------------------------------------------------------------
# Threshold: 0.835
# Accuracy: 28.16806072620026%
# -------------------------------------------------------------
# Threshold: 0.84
# Accuracy: 27.33162500604361%
# -------------------------------------------------------------
# Threshold: 0.845
# Accuracy: 26.56771261422424%
# -------------------------------------------------------------
# Threshold: 0.85
# Accuracy: 25.808635110960694%
# -------------------------------------------------------------
# Threshold: 0.855
# Accuracy: 24.962529613692404%
# -------------------------------------------------------------
# Threshold: 0.86
# Accuracy: 24.16960789053812%
# -------------------------------------------------------------
# Threshold: 0.865
# Accuracy: 23.221969733597643%
# -------------------------------------------------------------
# Threshold: 0.87
# Accuracy: 22.22598269109897%
# -------------------------------------------------------------
# Threshold: 0.875
# Accuracy: 21.22032587148866%
# -------------------------------------------------------------
# Threshold: 0.88
# Accuracy: 20.180824831987625%
# -------------------------------------------------------------
# Threshold: 0.885
# Accuracy: 18.99627713581202%
# -------------------------------------------------------------
# Threshold: 0.89
# Accuracy: 17.628003674515302%
# -------------------------------------------------------------
# Threshold: 0.895
# Accuracy: 16.2887395445535%
# -------------------------------------------------------------
# Threshold: 0.9
# Accuracy: 14.760914760914762%
# -------------------------------------------------------------
# Threshold: 0.905
# Accuracy: 13.305613305613306%
# -------------------------------------------------------------
# Threshold: 0.91
# Accuracy: 11.947009621428226%
# -------------------------------------------------------------
# Threshold: 0.915
# Accuracy: 10.201614852777643%
# -------------------------------------------------------------
# Threshold: 0.92
# Accuracy: 8.649615626359813%
# -------------------------------------------------------------
# Threshold: 0.925
# Accuracy: 7.034762848716338%
# -------------------------------------------------------------
# Threshold: 0.93
# Accuracy: 5.323212299956486%
# -------------------------------------------------------------
# Threshold: 0.935
# Accuracy: 4.0661412754436%
# -------------------------------------------------------------
# Threshold: 0.94
# Accuracy: 2.722042256925978%
# -------------------------------------------------------------
# Threshold: 0.945
# Accuracy: 1.8420925397669583%
# -------------------------------------------------------------
# Threshold: 0.95
# Accuracy: 1.1023545907266836%
# -------------------------------------------------------------
# Threshold: 0.955
# Accuracy: 0.6382052893680801%
# -------------------------------------------------------------
# Threshold: 0.96
# Accuracy: 0.3481119760189528%
# -------------------------------------------------------------
# Threshold: 0.965
# Accuracy: 0.18372576512111397%
# -------------------------------------------------------------
# Threshold: 0.97
# Accuracy: 0.06768843978146304%
# -------------------------------------------------------------
# Threshold: 0.975
# Accuracy: 0.014504665667456364%
# -------------------------------------------------------------
# Threshold: 0.98
# Accuracy: 0.0%
# -------------------------------------------------------------
# Threshold: 0.985
# Accuracy: 0.0%
# -------------------------------------------------------------
# Threshold: 0.99
# Accuracy: 0.0%
# -------------------------------------------------------------
# Threshold: 0.995
# Accuracy: 0.0%
# -------------------------------------------------------------
# Threshold: 1.0
# Accuracy: 0.0%

# %%
np.save(path + 'gfast_bigger_test_thresholds.npy', thresholds)
np.save(path + 'gfast_bigger_test_accuracies.npy', accuracies)
np.save(path + 'gfast_bigger_test_precisions.npy', precisions)
np.save(path + 'gfast_bigger_test_recalls.npy', recalls)
np.save(path + 'gfast_bigger_test_F1s.npy', F1s)

# %%
# Find threshold with highest accuracy

acc0 = 0

for idx in range(len(accuracies)):
    acc = accuracies[idx]
    if acc > acc0:
        acc0 = acc
        best_thresh = thresholds[idx] # Only updates when it hits a higher accuracy
        
print(best_thresh)
# Out:
# 0.0

# %%
best_thresh = 0.135

# %%
thresholds = np.load(path + 'gfast_bigger_test_thresholds.npy')
accuracies = np.load(path + 'gfast_bigger_test_accuracies.npy')
precisions = np.load(path + 'gfast_bigger_test_precisions.npy')
recalls = np.load(path + 'gfast_bigger_test_recalls.npy')
F1s = np.load(path + 'gfast_bigger_test_F1s.npy')

# %%
r = np.where(thresholds == 0.135)[0]
print(accuracies[r])
# Out:
# [0.56307112]

# %%
e = np.where(precisions == np.max(precisions))[0]
print(np.max(precisions))
print(thresholds[e])
print(accuracies[e])
# Out:
# 1.0
# [0.    0.005 0.01  0.015 0.02  0.025 0.03  0.035 0.04  0.045 0.05  0.055
#  0.06  0.065 0.07  0.075 0.08  0.085 0.09  0.095 0.1   0.105 0.11  0.115
#  0.12  0.125 0.13  0.135 0.14  0.145 0.15  0.155 0.16  0.165 0.17  0.175
#  0.18  0.185 0.19  0.195 0.2   0.205 0.21  0.215 0.22  0.225 0.23  0.235
#  0.24  0.245 0.25  0.255 0.26  0.265 0.27  0.275 0.28  0.285 0.29  0.295
#  0.3   0.305 0.31  0.315 0.32  0.325 0.33  0.335 0.34  0.345 0.35  0.355
#  0.36  0.365 0.37  0.375 0.38  0.385 0.39  0.395 0.4   0.405 0.41  0.415
#  0.42  0.425 0.43  0.435 0.44  0.445 0.45  0.455 0.46  0.465 0.47  0.475
#  0.48  0.485 0.49  0.495 0.5   0.505 0.51  0.515 0.52  0.525 0.53  0.535
#  0.54  0.545 0.55  0.555 0.56  0.565 0.57  0.575 0.58  0.585 0.59  0.595
#  0.6   0.605 0.61  0.615 0.62  0.625 0.63  0.635 0.64  0.645 0.65  0.655
#  0.66  0.665 0.67  0.675 0.68  0.685 0.69  0.695 0.7   0.705 0.71  0.715
#  0.72  0.725 0.73  0.735 0.74  0.745 0.75  0.755 0.76  0.765 0.77  0.775
#  0.78  0.785 0.79  0.795 0.8   0.805 0.81  0.815 0.82  0.825 0.83  0.835
#  0.84  0.845 0.85  0.855 0.86  0.865 0.87  0.875 0.88  0.885 0.89  0.895
#  0.9   0.905 0.91  0.915 0.92  0.925 0.93  0.935 0.94  0.945 0.95  0.955
#  0.96  0.965 0.97  0.975]
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 9.94198134e-01 9.56147561e-01
#  9.06009766e-01 8.62592467e-01 8.24251801e-01 7.92341537e-01
#  7.64589276e-01 7.39689600e-01 7.18996277e-01 6.99705072e-01
#  6.82734613e-01 6.67408016e-01 6.52226466e-01 6.38350336e-01
#  6.24715950e-01 6.13644056e-01 6.01991974e-01 5.93047430e-01
#  5.84296282e-01 5.76270367e-01 5.69259779e-01 5.63071121e-01
#  5.56108882e-01 5.50500411e-01 5.45182034e-01 5.40250447e-01
#  5.35560605e-01 5.31209206e-01 5.27534690e-01 5.24295315e-01
#  5.21877871e-01 5.19025286e-01 5.17236378e-01 5.15689213e-01
#  5.14045351e-01 5.12739931e-01 5.11434511e-01 5.10080743e-01
#  5.09210463e-01 5.07759996e-01 5.06599623e-01 5.05439250e-01
#  5.04520621e-01 5.03601992e-01 5.02538316e-01 5.01522990e-01
#  5.00604361e-01 4.99975826e-01 4.99153895e-01 4.97945172e-01
#  4.97461684e-01 4.96349659e-01 4.95624426e-01 4.94560750e-01
#  4.94125610e-01 4.93303679e-01 4.92336702e-01 4.91369724e-01
#  4.90547793e-01 4.90064304e-01 4.89000629e-01 4.87791906e-01
#  4.86969975e-01 4.86534835e-01 4.85616207e-01 4.84745927e-01
#  4.83972344e-01 4.83005367e-01 4.82183436e-01 4.81071411e-01
#  4.80249480e-01 4.79234154e-01 4.78557269e-01 4.77832036e-01
#  4.77300198e-01 4.76526616e-01 4.75946429e-01 4.74641010e-01
#  4.74060823e-01 4.73480636e-01 4.72803752e-01 4.71595030e-01
#  4.70773099e-01 4.69854470e-01 4.68694097e-01 4.67437026e-01
#  4.66276652e-01 4.65358023e-01 4.64584441e-01 4.63569115e-01
#  4.62166997e-01 4.60668182e-01 4.59797902e-01 4.58685877e-01
#  4.57622202e-01 4.56413480e-01 4.55253106e-01 4.53996035e-01
#  4.52884011e-01 4.52158778e-01 4.51046753e-01 4.50128125e-01
#  4.48726007e-01 4.47517285e-01 4.45970120e-01 4.44471305e-01
#  4.43020838e-01 4.41183581e-01 4.39539719e-01 4.38040903e-01
#  4.36251994e-01 4.34801528e-01 4.33447759e-01 4.32432432e-01
#  4.31078664e-01 4.29821593e-01 4.28032684e-01 4.26437171e-01
#  4.24890006e-01 4.23487889e-01 4.22230818e-01 4.20441909e-01
#  4.18653000e-01 4.16573998e-01 4.14978485e-01 4.13189576e-01
#  4.11158923e-01 4.09176618e-01 4.07194314e-01 4.04970265e-01
#  4.03229706e-01 4.01247401e-01 3.99216748e-01 3.96605908e-01
#  3.94430208e-01 3.92302857e-01 3.89982111e-01 3.87564667e-01
#  3.84470338e-01 3.81762800e-01 3.78765169e-01 3.75139003e-01
#  3.72334768e-01 3.69337137e-01 3.65710970e-01 3.62084804e-01
#  3.58120195e-01 3.53913842e-01 3.49514094e-01 3.45162694e-01
#  3.40859643e-01 3.37330175e-01 3.32591984e-01 3.27708746e-01
#  3.22873858e-01 3.17555480e-01 3.11898661e-01 3.05661654e-01
#  3.00488324e-01 2.93477735e-01 2.87724218e-01 2.81680607e-01
#  2.73316250e-01 2.65677126e-01 2.58086351e-01 2.49625296e-01
#  2.41696079e-01 2.32219697e-01 2.22259827e-01 2.12203259e-01
#  2.01808248e-01 1.89962771e-01 1.76280037e-01 1.62887395e-01
#  1.47609148e-01 1.33056133e-01 1.19470096e-01 1.02016149e-01
#  8.64961563e-02 7.03476285e-02 5.32321230e-02 4.06614128e-02
#  2.72204226e-02 1.84209254e-02 1.10235459e-02 6.38205289e-03
#  3.48111976e-03 1.83725765e-03 6.76884398e-04 1.45046657e-04]

# %%
e = np.where(recalls == np.max(recalls))[0]
print(np.max(recalls))
print(thresholds[e])
print(accuracies[e])
# Out:
# 1.0
# [0.    0.005 0.01  0.015 0.02  0.025]
# [1. 1. 1. 1. 1. 1.]

# %%
e = np.where(F1s == np.max(F1s))[0]
print(np.max(F1s))
print(thresholds[e])
print(accuracies[e])
# Out:
# 1.0
# [0.    0.005 0.01  0.015 0.02  0.025]
# [1. 1. 1. 1. 1. 1.]

# %%
# Subplot version

# %%
plt.figure(figsize = (8,5), dpi = 400)

plt.subplot(221)
plt.text(x = -0.3, y = 0.9, s = '(a)', fontsize = 22)
plt.grid(lw = 0.5, zorder = 0)
plt.plot(thresholds, accuracies, linewidth = 2)
plt.ylabel('Accuracy', fontsize = 12)
plt.xlim(0,1)
plt.ylim(0,1)
plt.axvline(best_thresh, color = 'red', linestyle = '--', alpha = 0.6, label = 'Max accuracy at threshold of ' + str(best_thresh))
plt.tick_params(axis = 'both', bottom = False, labelbottom = False)
plt.yticks(fontsize = 11)
plt.legend(loc = (0.55,-1.45))

# plt.legend()

plt.subplot(222)
plt.text(x = -0.3, y = 0.9, s = '(b)', fontsize = 22)
plt.grid(lw = 0.5, zorder = 0)
plt.plot(thresholds, precisions, linewidth = 2)
plt.ylabel('Precision', fontsize = 12)
plt.xlim(0,1)
plt.ylim(0,1)
plt.tick_params(axis = 'both', bottom = False, labelbottom = False)
plt.axvline(best_thresh, color = 'red', linestyle = '--', alpha = 0.6)
plt.yticks(fontsize = 11)


plt.subplot(223)
plt.text(x = -0.3, y = 0.9, s = '(c)', fontsize = 22)
plt.grid(lw = 0.5, zorder = 0)
plt.plot(thresholds, recalls, linewidth = 2)
plt.xlabel('Threshold', fontsize = 12)
plt.ylabel('Recall', fontsize = 12)
plt.xlim(0,1)
plt.ylim(0,1)
plt.xticks(fontsize = 11)
plt.yticks([0, 0.2, 0.4, 0.6, 0.8], fontsize = 11)
plt.axvline(best_thresh, color = 'red', linestyle = '--', alpha = 0.6)

plt.subplot(224)
plt.text(x = -0.3, y = 0.9, s = '(d)', fontsize = 22)
plt.grid(lw = 0.5, zorder = 0)
plt.plot(thresholds, F1s, linewidth = 2)
plt.xlabel('Threshold', fontsize = 12)
plt.ylabel('F1', fontsize = 12)
plt.xlim(0,1)
plt.ylim(0,1)
plt.xticks(fontsize = 11)
plt.yticks([0, 0.2, 0.4, 0.6, 0.8], fontsize = 11)
plt.axvline(best_thresh, color = 'red', linestyle = '--', alpha = 0.6)

plt.subplots_adjust(hspace = 0, wspace = 0.32, bottom = 0.2)

plt.show()

# plt.savefig('/home/sdybing/gnss-picker/manuscript_figures/fq_testdata_classification.jpg', format = 'JPG')
# plt.close();
