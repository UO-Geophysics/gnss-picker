# %%
import numpy as np
import matplotlib.pyplot as plt

project = 'newfault'
traindate = '2024-10-01'
testdate = '2024-10-02'
traindate_path = '/home/sdybing/gnss-picker/cnn_models_outputs/' + project + '_fq_train/models/traindate_' + traindate + '/'
test_outputs_path = traindate_path + 'data/'
figure_save_dir = traindate_path + 'figures/'
best_thresh = 0.135 # From code 2

results = np.load(test_outputs_path + 'fakequakes_testing/fqtest_metadata_with_results_pgd_snr.npy')
# Columns:

# 0: FQ rupture name
# 1: station name
# 2: magnitude
# 3: result (true pos, etc.)
# 4: PGD
# 5: SNR_N
# 6: SNR_E
# 7: SNR_Z

# %%
mags = []

for idx in range(len(results)):
    mag = results[idx,2]
    if mag != 'nan':
        mags.append(mag)

print(len(mags))
print(min(mags))
print(max(mags))
# Out:
# 45870
# 3.6167
# 7.7934

# %%
mags_35375 = []
mags_3754 = []
mags_4425 = []
mags_42545 = []
mags_45475 = []
mags_4755 = []
mags_5525 = []
mags_52555 = []
mags_55575 = []
mags_5756 = []
mags_6625 = []
mags_62565 = []
mags_65675 = []
mags_6757 = []
mags_7725 = []
mags_72575 = []
mags_75775 = []
mags_7758 = []

list_of_bins = [mags_35375, mags_3754, mags_4425, mags_42545, mags_45475, mags_4755, mags_5525, mags_52555, mags_55575, mags_5756, mags_6625, mags_62565, mags_65675, mags_6757, mags_7725, mags_72575, mags_75775, mags_7758]

true_pos = []
false_neg = []

for i in range(len(results)):
    
    if results[i][0] == 'nan':
        pass
    
    else:
        mag = float(results[i][2])
        result = results[i][3]
        
        if mag <= 3.75:
            mags_35375.append(i)    
        elif mag > 3.75 and mag <= 4:
            mags_3754.append(i)
        elif mag > 4 and mag <= 4.25:
            mags_4425.append(i)
        elif mag > 4.25 and mag <= 4.5:
            mags_42545.append(i)
        elif mag > 4.5 and mag <= 4.75:
            mags_45475.append(i)
        elif mag > 4.75 and mag <= 5:
            mags_4755.append(i)
        elif mag > 5 and mag <= 5.25:
            mags_5525.append(i)
        elif mag > 5.25 and mag <= 5.5:
            mags_52555.append(i)
        elif mag > 5.5 and mag <= 5.75:
            mags_55575.append(i)
        elif mag > 5.75 and mag <= 6:
            mags_5756.append(i)
        elif mag > 6 and mag <= 6.25:
            mags_6625.append(i)        
        elif mag > 6.25 and mag <= 6.5:
            mags_62565.append(i)            
        elif mag > 6.5 and mag <= 6.75:
            mags_65675.append(i)        
        elif mag > 6.75 and mag <= 7:
            mags_6757.append(i)        
        elif mag > 7 and mag <= 7.25:
            mags_7725.append(i)        
        elif mag > 7.25 and mag <= 7.5:
            mags_72575.append(i)
        elif mag > 7.5 and mag <= 7.75:
            mags_75775.append(i)
        elif mag > 7.75 and mag <= 8:
            mags_7758.append(i)
        
        if result == 'true pos': # predicted 1, target 1
            true_pos.append(1)
        
        elif result == 'false neg': # predicted 0, target 1
            false_neg.append(1)
            
        else:
            print('Error at i ' + str(i))

# %%
number_correct = len(true_pos)
number_incorrect = len(false_neg)
total_number = number_correct + number_incorrect

print('True positive: ' + str(number_correct))
print('False negative: ' + str(number_incorrect))
print('Total number: ' + str(total_number))
print('Overall accuracy: ' + str(100*(np.round(number_correct/total_number,3))) + '%')
# Out:
# True positive: 10476
# False negative: 35394
# Total number: 45870
# Overall accuracy: 22.8%

# %%
a = 0
for idx in list_of_bins:
    a += len(idx)
print(a)
# Out:
# 45870

# %%
accuracy_percentages = []

print(' ')
print('-------------------------------------------------------------')
print('Earthquakes M3.5-3.75')
print('-------------------------------------------------------------')

truepos_35375 = []
falseneg_35375 = []

for index in mags_35375:
    
    # print(index)
    event_row = results[index]
    # print(event_row)
    
    result = event_row[3]
    # print(result)
    
    if result == 'true pos':
        truepos_35375.append(1)
    elif result == 'false neg':
        falseneg_35375.append(1)
        
number_correct_35375 = len(truepos_35375)
number_incorrect_35375 = len(falseneg_35375)
total_number_35375 = number_correct_35375 + number_incorrect_35375

print('True positive: ' + str(number_correct_35375))
print('False negative: ' + str(number_incorrect_35375))
print('Total number: ' + str(total_number_35375))
print('Accuracy: ' + str(100*(np.round(number_correct_35375/total_number_35375,4))) + '%')

accuracy_35375 = 100*(np.round(number_correct_35375/total_number_35375,4))
accuracy_percentages.append(accuracy_35375)

print(' ')
print('-------------------------------------------------------------')
print('Earthquakes M3.75-4')
print('-------------------------------------------------------------')

truepos_3754 = []
falseneg_3754 = []

for index in mags_3754:
    
    # print(index)
    event_row = results[index]
    # print(event_row)
    
    result = event_row[3]
    # print(result)
    
    if result == 'true pos':
        truepos_3754.append(1)
    elif result == 'false neg':
        falseneg_3754.append(1)
        
number_correct_3754 = len(truepos_3754)
number_incorrect_3754 = len(falseneg_3754)
total_number_3754 = number_correct_3754 + number_incorrect_3754

print('True positive: ' + str(number_correct_3754))
print('False negative: ' + str(number_incorrect_3754))
print('Total number: ' + str(total_number_3754))
print('Accuracy: ' + str(100*(np.round(number_correct_3754/total_number_3754,4))) + '%')

accuracy_3754 = 100*(np.round(number_correct_3754/total_number_3754,4))
accuracy_percentages.append(accuracy_3754)

print(' ')
print('-------------------------------------------------------------')
print('Earthquakes M4-4.25')
print('-------------------------------------------------------------')

truepos_4425 = []
falseneg_4425 = []

for index in mags_4425:
    
    # print(index)
    event_row = results[index]
    # print(event_row)
    
    result = event_row[3]
    # print(result)
    
    if result == 'true pos':
        truepos_4425.append(1)
    elif result == 'false neg':
        falseneg_4425.append(1)
        
number_correct_4425 = len(truepos_4425)
number_incorrect_4425 = len(falseneg_4425)
total_number_4425 = number_correct_4425 + number_incorrect_4425

print('True positive: ' + str(number_correct_4425))
print('False negative: ' + str(number_incorrect_4425))
print('Total number: ' + str(total_number_4425))
print('Accuracy: ' + str(100*(np.round(number_correct_4425/total_number_4425,4))) + '%')

accuracy_4425 = 100*(np.round(number_correct_4425/total_number_4425,4))
accuracy_percentages.append(accuracy_4425)

print(' ')
print('-------------------------------------------------------------')
print('Earthquakes M4.25-4.5')
print('-------------------------------------------------------------')

truepos_42545 = []
falseneg_42545 = []

for index in mags_42545:
    
    # print(index)
    event_row = results[index]
    # print(event_row)
    
    result = event_row[3]
    # print(result)
    
    if result == 'true pos':
        truepos_42545.append(1)
    elif result == 'false neg':
        falseneg_42545.append(1)
        
number_correct_42545 = len(truepos_42545)
number_incorrect_42545 = len(falseneg_42545)
total_number_42545 = number_correct_42545 + number_incorrect_42545

print('True positive: ' + str(number_correct_42545))
print('False negative: ' + str(number_incorrect_42545))
print('Total number: ' + str(total_number_42545))
print('Accuracy: ' + str(100*(np.round(number_correct_42545/total_number_42545,4))) + '%')

accuracy_42545 = 100*(np.round(number_correct_42545/total_number_42545,4))
accuracy_percentages.append(accuracy_42545)

print(' ')
print('-------------------------------------------------------------')
print('Earthquakes M4.5-4.75')
print('-------------------------------------------------------------')

truepos_45475 = []
falseneg_45475 = []

for index in mags_45475:
    
    # print(index)
    event_row = results[index]
    # print(event_row)
    
    result = event_row[3]
    # print(result)
    
    if result == 'true pos':
        truepos_45475.append(1)
    elif result == 'false neg':
        falseneg_45475.append(1)
        
number_correct_45475 = len(truepos_45475)
number_incorrect_45475 = len(falseneg_45475)
total_number_45475 = number_correct_45475 + number_incorrect_45475

print('True positive: ' + str(number_correct_45475))
print('False negative: ' + str(number_incorrect_45475))
print('Total number: ' + str(total_number_45475))
print('Accuracy: ' + str(100*(np.round(number_correct_45475/total_number_45475,4))) + '%')

accuracy_45475 = 100*(np.round(number_correct_45475/total_number_45475,4))
accuracy_percentages.append(accuracy_45475)

print(' ')
print('-------------------------------------------------------------')
print('Earthquakes M4.75-5')
print('-------------------------------------------------------------')

truepos_4755 = []
falseneg_4755 = []

for index in mags_4755:
    
    # print(index)
    event_row = results[index]
    # print(event_row)
    
    result = event_row[3]
    # print(result)
    
    if result == 'true pos':
        truepos_4755.append(1)
    elif result == 'false neg':
        falseneg_4755.append(1)
        
number_correct_4755 = len(truepos_4755)
number_incorrect_4755 = len(falseneg_4755)
total_number_4755 = number_correct_4755 + number_incorrect_4755

print('True positive: ' + str(number_correct_4755))
print('False negative: ' + str(number_incorrect_4755))
print('Total number: ' + str(total_number_4755))
print('Accuracy: ' + str(100*(np.round(number_correct_4755/total_number_4755,4))) + '%')

accuracy_4755 = 100*(np.round(number_correct_4755/total_number_4755,4))
accuracy_percentages.append(accuracy_4755)

print(' ')
print('-------------------------------------------------------------')
print('Earthquakes M5-5.25')
print('-------------------------------------------------------------')

truepos_5525 = []
falseneg_5525 = []

for index in mags_5525:
    
    # print(index)
    event_row = results[index]
    # print(event_row)
    
    result = event_row[3]
    # print(result)
    
    if result == 'true pos':
        truepos_5525.append(1)
    elif result == 'false neg':
        falseneg_5525.append(1)
        
number_correct_5525 = len(truepos_5525)
number_incorrect_5525 = len(falseneg_5525)
total_number_5525 = number_correct_5525 + number_incorrect_5525

print('True positive: ' + str(number_correct_5525))
print('False negative: ' + str(number_incorrect_5525))
print('Total number: ' + str(total_number_5525))
print('Accuracy: ' + str(100*(np.round(number_correct_5525/total_number_5525,4))) + '%')

accuracy_5525 = 100*(np.round(number_correct_5525/total_number_5525,4))
accuracy_percentages.append(accuracy_5525)

print(' ')
print('-------------------------------------------------------------')
print('Earthquakes M5.25-5.5')
print('-------------------------------------------------------------')

truepos_52555 = []
falseneg_52555 = []

for index in mags_52555:
    
    # print(index)
    event_row = results[index]
    # print(event_row)
    
    result = event_row[3]
    # print(result)
    
    if result == 'true pos':
        truepos_52555.append(1)
    elif result == 'false neg':
        falseneg_52555.append(1)
        
number_correct_52555 = len(truepos_52555)
number_incorrect_52555 = len(falseneg_52555)
total_number_52555 = number_correct_52555 + number_incorrect_52555

print('True positive: ' + str(number_correct_52555))
print('False negative: ' + str(number_incorrect_52555))
print('Total number: ' + str(total_number_52555))
print('Accuracy: ' + str(100*(np.round(number_correct_52555/total_number_52555,4))) + '%')

accuracy_52555 = 100*(np.round(number_correct_52555/total_number_52555,4))
accuracy_percentages.append(accuracy_52555)

print(' ')
print('-------------------------------------------------------------')
print('Earthquakes M5.5-5.75')
print('-------------------------------------------------------------')

truepos_55575 = []
falseneg_55575 = []

for index in mags_55575:
    
    # print(index)
    event_row = results[index]
    # print(event_row)
    
    result = event_row[3]
    # print(result)
    
    if result == 'true pos':
        truepos_55575.append(1)
    elif result == 'false neg':
        falseneg_55575.append(1)
        
number_correct_55575 = len(truepos_55575)
number_incorrect_55575 = len(falseneg_55575)
total_number_55575 = number_correct_55575 + number_incorrect_55575

print('True positive: ' + str(number_correct_55575))
print('False negative: ' + str(number_incorrect_55575))
print('Total number: ' + str(total_number_55575))
print('Accuracy: ' + str(100*(np.round(number_correct_55575/total_number_55575,4))) + '%')

accuracy_55575 = 100*(np.round(number_correct_55575/total_number_55575,4))
accuracy_percentages.append(accuracy_55575)

print(' ')
print('-------------------------------------------------------------')
print('Earthquakes M5.75-6')
print('-------------------------------------------------------------')

truepos_5756 = []
falseneg_5756 = []

for index in mags_5756:
    
    # print(index)
    event_row = results[index]
    # print(event_row)
    
    result = event_row[3]
    # print(result)
    
    if result == 'true pos':
        truepos_5756.append(1)
    elif result == 'false neg':
        falseneg_5756.append(1)
        
number_correct_5756 = len(truepos_5756)
number_incorrect_5756 = len(falseneg_5756)
total_number_5756 = number_correct_5756 + number_incorrect_5756

print('True positive: ' + str(number_correct_5756))
print('False negative: ' + str(number_incorrect_5756))
print('Total number: ' + str(total_number_5756))
print('Accuracy: ' + str(100*(np.round(number_correct_5756/total_number_5756,4))) + '%')

accuracy_5756 = 100*(np.round(number_correct_5756/total_number_5756,4))
accuracy_percentages.append(accuracy_5756)

print(' ')
print('-------------------------------------------------------------')
print('Earthquakes M6-6.25')
print('-------------------------------------------------------------')

truepos_6625 = []
falseneg_6625 = []

for index in mags_6625:
    
    # print(index)
    event_row = results[index]
    # print(event_row)
    
    result = event_row[3]
    # print(result)
    
    if result == 'true pos':
        truepos_6625.append(1)
    elif result == 'false neg':
        falseneg_6625.append(1)
        
number_correct_6625 = len(truepos_6625)
number_incorrect_6625 = len(falseneg_6625)
total_number_6625 = number_correct_6625 + number_incorrect_6625

print('True positive: ' + str(number_correct_6625))
print('False negative: ' + str(number_incorrect_6625))
print('Total number: ' + str(total_number_6625))
print('Accuracy: ' + str(100*(np.round(number_correct_6625/total_number_6625,4))) + '%')

accuracy_6625 = 100*(np.round(number_correct_6625/total_number_6625,4))
accuracy_percentages.append(accuracy_6625)

print(' ')
print('-------------------------------------------------------------')
print('Earthquakes M6.25-6.5')
print('-------------------------------------------------------------')

truepos_62565 = []
falseneg_62565 = []

for index in mags_62565:
    
    # print(index)
    event_row = results[index]
    # print(event_row)
    
    result = event_row[3]
    # print(result)
    
    if result == 'true pos':
        truepos_62565.append(1)
    elif result == 'false neg':
        falseneg_62565.append(1)
        
number_correct_62565 = len(truepos_62565)
number_incorrect_62565 = len(falseneg_62565)
total_number_62565 = number_correct_62565 + number_incorrect_62565

print('True positive: ' + str(number_correct_62565))
print('False negative: ' + str(number_incorrect_62565))
print('Total number: ' + str(total_number_62565))
print('Accuracy: ' + str(100*(np.round(number_correct_62565/total_number_62565,4))) + '%')

accuracy_62565 = 100*(np.round(number_correct_62565/total_number_62565,4))
accuracy_percentages.append(accuracy_62565)

print(' ')
print('-------------------------------------------------------------')
print('Earthquakes M6.5-6.75')
print('-------------------------------------------------------------')

truepos_65675 = []
falseneg_65675 = []

for index in mags_65675:
    
    # print(index)
    event_row = results[index]
    # print(event_row)
    
    result = event_row[3]
    # print(result)
    
    if result == 'true pos':
        truepos_65675.append(1)
    elif result == 'false neg':
        falseneg_65675.append(1)
        
number_correct_65675 = len(truepos_65675)
number_incorrect_65675 = len(falseneg_65675)
total_number_65675 = number_correct_65675 + number_incorrect_65675

print('True positive: ' + str(number_correct_65675))
print('False negative: ' + str(number_incorrect_65675))
print('Total number: ' + str(total_number_65675))
print('Accuracy: ' + str(100*(np.round(number_correct_65675/total_number_65675,4))) + '%')

accuracy_65675 = 100*(np.round(number_correct_65675/total_number_65675,4))
accuracy_percentages.append(accuracy_65675)

print(' ')
print('-------------------------------------------------------------')
print('Earthquakes M6.75-7')
print('-------------------------------------------------------------')

truepos_6757 = []
falseneg_6757 = []

for index in mags_6757:
    
    # print(index)
    event_row = results[index]
    # print(event_row)
    
    result = event_row[3]
    # print(result)
    
    if result == 'true pos':
        truepos_6757.append(1)
    elif result == 'false neg':
        falseneg_6757.append(1)
        
number_correct_6757 = len(truepos_6757)
number_incorrect_6757 = len(falseneg_6757)
total_number_6757 = number_correct_6757 + number_incorrect_6757

print('True positive: ' + str(number_correct_6757))
print('False negative: ' + str(number_incorrect_6757))
print('Total number: ' + str(total_number_6757))
print('Accuracy: ' + str(100*(np.round(number_correct_6757/total_number_6757,4))) + '%')

accuracy_6757 = 100*(np.round(number_correct_6757/total_number_6757,4))
accuracy_percentages.append(accuracy_6757)

print(' ')
print('-------------------------------------------------------------')
print('Earthquakes M7-7.25')
print('-------------------------------------------------------------')

truepos_7725 = []
falseneg_7725 = []

for index in mags_7725:
    
    # print(index)
    event_row = results[index]
    # print(event_row)
    
    result = event_row[3]
    # print(result)
    
    if result == 'true pos':
        truepos_7725.append(1)
    elif result == 'false neg':
        falseneg_7725.append(1)
        
number_correct_7725 = len(truepos_7725)
number_incorrect_7725 = len(falseneg_7725)
total_number_7725 = number_correct_7725 + number_incorrect_7725

print('True positive: ' + str(number_correct_7725))
print('False negative: ' + str(number_incorrect_7725))
print('Total number: ' + str(total_number_7725))
print('Accuracy: ' + str(100*(np.round(number_correct_7725/total_number_7725,4))) + '%')

accuracy_7725 = 100*(np.round(number_correct_7725/total_number_7725,4))
accuracy_percentages.append(accuracy_7725)

print(' ')
print('-------------------------------------------------------------')
print('Earthquakes M7.25-7.5')
print('-------------------------------------------------------------')

truepos_72575 = []
falseneg_72575 = []

for index in mags_72575:
    
    # print(index)
    event_row = results[index]
    # print(event_row)
    
    result = event_row[3]
    # print(result)
    
    if result == 'true pos':
        truepos_72575.append(1)
    elif result == 'false neg':
        falseneg_72575.append(1)
        
number_correct_72575 = len(truepos_72575)
number_incorrect_72575 = len(falseneg_72575)
total_number_72575 = number_correct_72575 + number_incorrect_72575

print('True positive: ' + str(number_correct_72575))
print('False negative: ' + str(number_incorrect_72575))
print('Total number: ' + str(total_number_72575))
print('Accuracy: ' + str(100*(np.round(number_correct_72575/total_number_72575,4))) + '%')

accuracy_72575 = 100*(np.round(number_correct_72575/total_number_72575,4))
accuracy_percentages.append(accuracy_72575)

print(' ')
print('-------------------------------------------------------------')
print('Earthquakes M7.5-7.75')
print('-------------------------------------------------------------')

truepos_75775 = []
falseneg_75775 = []

for index in mags_75775:
    
    # print(index)
    event_row = results[index]
    # print(event_row)
    
    result = event_row[3]
    # print(result)
    
    if result == 'true pos':
        truepos_75775.append(1)
    elif result == 'false neg':
        falseneg_75775.append(1)
        
number_correct_75775 = len(truepos_75775)
number_incorrect_75775 = len(falseneg_75775)
total_number_75775 = number_correct_75775 + number_incorrect_75775

print('True positive: ' + str(number_correct_75775))
print('False negative: ' + str(number_incorrect_75775))
print('Total number: ' + str(total_number_75775))
print('Accuracy: ' + str(100*(np.round(number_correct_75775/total_number_75775,4))) + '%')

accuracy_75775 = 100*(np.round(number_correct_75775/total_number_75775,4))
accuracy_percentages.append(accuracy_75775)

print(' ')
print('-------------------------------------------------------------')
print('Earthquakes M7.75-8')
print('-------------------------------------------------------------')

truepos_7758 = []
falseneg_7758 = []

for index in mags_7758:
    
    # print(index)
    event_row = results[index]
    # print(event_row)
    
    result = event_row[3]
    # print(result)
    
    if result == 'true pos':
        truepos_7758.append(1)
    elif result == 'false neg':
        falseneg_7758.append(1)
        
number_correct_7758 = len(truepos_7758)
number_incorrect_7758 = len(falseneg_7758)
total_number_7758 = number_correct_7758 + number_incorrect_7758

print('True positive: ' + str(number_correct_7758))
print('False negative: ' + str(number_incorrect_7758))
print('Total number: ' + str(total_number_7758))
print('Accuracy: ' + str(100*(np.round(number_correct_7758/total_number_7758,4))) + '%')

accuracy_7758 = 100*(np.round(number_correct_7758/total_number_7758,4))
accuracy_percentages.append(accuracy_7758)
# Out:
#
# -------------------------------------------------------------
# Earthquakes M3.5-3.75
# -------------------------------------------------------------
# True positive: 4
# False negative: 40
# Total number: 44
# Accuracy: 9.09%
#
# -------------------------------------------------------------
# Earthquakes M3.75-4
# -------------------------------------------------------------
# True positive: 14
# False negative: 374
# Total number: 388
# Accuracy: 3.61%
#
# -------------------------------------------------------------
# Earthquakes M4-4.25
# -------------------------------------------------------------
# True positive: 50
# False negative: 1578
# Total number: 1628
# Accuracy: 3.0700000000000003%
#
# -------------------------------------------------------------
# Earthquakes M4.25-4.5
# -------------------------------------------------------------
# True positive: 91
# False negative: 2608
# Total number: 2699
# Accuracy: 3.37%
#
# -------------------------------------------------------------
# Earthquakes M4.5-4.75
# -------------------------------------------------------------
# True positive: 111
# False negative: 3123
# Total number: 3234
# Accuracy: 3.4299999999999997%
#
# -------------------------------------------------------------
# Earthquakes M4.75-5
# -------------------------------------------------------------
# True positive: 129
# False negative: 3577
# Total number: 3706
# Accuracy: 3.4799999999999995%
#
# -------------------------------------------------------------
# Earthquakes M5-5.25
# -------------------------------------------------------------
# True positive: 125
# False negative: 3271
# Total number: 3396
# Accuracy: 3.6799999999999997%
#
# -------------------------------------------------------------
# Earthquakes M5.25-5.5
# -------------------------------------------------------------
# True positive: 111
# False negative: 3228
# Total number: 3339
# Accuracy: 3.32%
#
# -------------------------------------------------------------
# Earthquakes M5.5-5.75
# -------------------------------------------------------------
# True positive: 122
# False negative: 3024
# Total number: 3146
# Accuracy: 3.88%
#
# -------------------------------------------------------------
# Earthquakes M5.75-6
# -------------------------------------------------------------
# True positive: 128
# False negative: 3479
# Total number: 3607
# Accuracy: 3.55%
#
# -------------------------------------------------------------
# Earthquakes M6-6.25
# -------------------------------------------------------------
# True positive: 199
# False negative: 3432
# Total number: 3631
# Accuracy: 5.48%
#
# -------------------------------------------------------------
# Earthquakes M6.25-6.5
# -------------------------------------------------------------
# True positive: 504
# False negative: 2776
# Total number: 3280
# Accuracy: 15.370000000000001%
#
# -------------------------------------------------------------
# Earthquakes M6.5-6.75
# -------------------------------------------------------------
# True positive: 1113
# False negative: 2285
# Total number: 3398
# Accuracy: 32.75%
#
# -------------------------------------------------------------
# Earthquakes M6.75-7
# -------------------------------------------------------------
# True positive: 1939
# False negative: 1423
# Total number: 3362
# Accuracy: 57.67%
#
# -------------------------------------------------------------
# Earthquakes M7-7.25
# -------------------------------------------------------------
# True positive: 2797
# False negative: 802
# Total number: 3599
# Accuracy: 77.72%
#
# -------------------------------------------------------------
# Earthquakes M7.25-7.5
# -------------------------------------------------------------
# True positive: 2402
# False negative: 315
# Total number: 2717
# Accuracy: 88.41%
#
# -------------------------------------------------------------
# Earthquakes M7.5-7.75
# -------------------------------------------------------------
# True positive: 620
# False negative: 58
# Total number: 678
# Accuracy: 91.45%
#
# -------------------------------------------------------------
# Earthquakes M7.75-8
# -------------------------------------------------------------
# True positive: 17
# False negative: 1
# Total number: 18
# Accuracy: 94.44%

# %%
# Plotting accuracies for 0.25 bins

bar_positions = [3.5, 3.75, 4, 4.25, 4.5, 4.75, 5, 5.25, 5.5, 5.75, 6, 6.25, 6.5, 6.75, 7, 7.25, 7.5, 7.75]

print(len(bar_positions))
print(len(accuracy_percentages))

plt.figure(figsize = (9,5.25), facecolor = 'white', dpi = 300)
# plt.figure(figsize = (9,5))
plt.grid(axis = 'y', zorder = 0)
plt.bar(bar_positions, accuracy_percentages, width = 0.25, color = 'lightskyblue', align = 'edge', edgecolor = 'black', zorder = 3)
plt.xlim(3.5,8)
plt.ylim(0,100)
# plt.xticks([5.75,6,6.25,6.5,6.75,7,7.25,7.5])
plt.ylabel('Accuracy (%)', fontsize = 16)
plt.xlabel('Magnitude', fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.suptitle('Magnitude', fontsize = 17)
plt.title('Algorithm accuracy (threshold = ' + str(best_thresh) + ')', fontsize = 15)

# plt.show();
plt.savefig(figure_save_dir + 'fakequakes_testing/binned_mag_accuracy.png', format = 'PNG')
plt.close();
# Out:
# 18
# 18
