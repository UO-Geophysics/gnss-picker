# %%
import numpy as np
from parallelized_random_noise_picker_fn import noise_picker
import multiprocessing as mp

# %%
ncpus = 40
# ncpus = 2
num_samples = 917400 * 2 # minimum is length of fakequakes data x 2 for the noise part 
# num_samples = 10
samples_per_cpu = num_samples / ncpus

# Set up for Tunguska currently

stas = np.genfromtxt('/home/sdybing/gnss-picker/GNSS_stas.txt', usecols=[2], dtype=str) # Stations the GNSS data came from
dates = np.genfromtxt('/home/sdybing/gnss-picker/GNSS_dates.txt', dtype=str) # List of the days in the GNSS file format

noise_data_path = '/hdd/Ridgecrest/mseeds/'
write_sample_path = '/home/sdybing/gnss-picker/noise_samples/mseeds/'
save_npy_path = '/home/sdybing/gnss-picker/noise_samples/npys/'
progress_report_path = '/home/sdybing/gnss-picker/noise_samples/prog_reps/'

save_npy_name = 'summer23_noise_samples.npy'

# %%
if __name__ ==  '__main__':

    jobs = []
    for cpu_number in range(ncpus):
        p = mp.Process(target = noise_picker, args = (stas, dates, samples_per_cpu, noise_data_path, write_sample_path, cpu_number, save_npy_path, save_npy_name, progress_report_path))
        jobs.append(p)
        p.start()
# Out:
# 20190726 gets skipped - earthquake day
# Date 20200218 is not there for station P727
# Date 20190930 is not there for station GR8R
# Date 20200704 is not there for station ISLK
# Date 20190826 is not there for station HOGS
# Date 20191216 is not there for station P608
# Date 20200605 is not there for station P604
# Date 20190818 is not there for station P279
# Date 20200513 is not there for station P093
# Date 20200523 is not there for station P607
# Date 20191019 is not there for station P565
# Date 20191216 is not there for station P527
# Date 20190827 is not there for station P489
# Date 20200403 is not there for station THMS
# Date 20200313 is not there for station P603
# Date 20191006 is not there for station P519
# Date 20190614 is not there for station P619
# Date 20190625 is not there for station P727
# Date 20190826 is not there for station P284
# Date 20200328 is not there for station P285
# Date 20200731 is not there for station P586
# Date 20200228 is not there for station P547
# Date 20200731 is not there for station P619
# **--**--** Success: station PEA2 for 20200104; 1/45870 samples for CPU 23 **--**--**
# Date 20191113 is not there for station P607
# Date 20190731 is not there for station MIDA
# Date 20190826 is not there for station VIMT
# Date 20200631 is not there for station P540
# Date 20190825 is not there for station OCSD
# Station EWPP for date 20200419: time pick failed
# Station ECFS for date 20200607: time pick failed
# Date 20200317 is not there for station CDMTStation P598 for date 20190807: time pick failed
#
# Date 20191116 is not there for station P067
# Date 20200304 is not there for station SONG
# Station P810 for date 20191023: time pick failed
# **--**--** Success: station P467 for 20200321; 1/45870 samples for CPU 37 **--**--**
# 20190706 gets skipped - earthquake day
# Date 20200415 is not there for station SHOS
# Date 20190816 is not there for station P285
# Station LDSW for date 20200612: time pick failed
# Date 20200516 is not there for station P006
# Date 20200512 is not there for station P525
# Date 20191227 is not there for station AR53
# Date 20200314 is not there for station P489
# Date 20200522 is not there for station P581
# Date 20200525 is not there for station P530
# Date 20191113 is not there for station FGST
# Station P598 for date 20200307: time pick failed
# **--**--** Success: station P606 for 20191118; 1/45870 samples for CPU 9 **--**--**
# Date 20190616 is not there for station P486
# Date 20200210 is not there for station RMVJ
# Station BBDM for date 20200525: time pick failed
# **--**--** Success: station P521 for 20191022; 1/45870 samples for CPU 1 **--**--**
# Station CAT2 for date 20191115: time pick failed
# Date 20200431 is not there for station MIG1
# Date 20190609 is not there for station OVLS
# **--**--** Success: station ACSX for 20200720; 1/45870 samples for CPU 3 **--**--**
# Date 20200124 is not there for station P536
# Date 20200613 is not there for station COPR
# Date 20191011 is not there for station CRBT
# **--**--** Success: station VNCO for 20200201; 1/45870 samples for CPU 33 **--**--**
# **--**--** Success: station P639 for 20191208; 1/45870 samples for CPU 34 **--**--**
# Date 20190610 is not there for station P581
# Date 20200416 is not there for station P489
# **--**--** Success: station P812 for 20200414; 1/45870 samples for CPU 13 **--**--**
# Date 20200610 is not there for station P568
# **--**--** Success: station MPWD for 20191003; 1/45870 samples for CPU 17 **--**--**
# **--**--** Success: station RCSC for 20200209; 1/45870 samples for CPU 2 **--**--**
# Date 20200528 is not there for station P567
# Date 20200516 is not there for station CNPP
# **--**--** Success: station FMVT for 20191008; 1/45870 samples for CPU 21 **--**--**
# **--**--** Success: station LFRS for 20190604; 1/45870 samples for CPU 20 **--**--**
# Station ECFS for date 20200422: time pick failed
# Date 20190808 is not there for station PVRS
# **--**--** Success: station P580 for 20191127; 1/45870 samples for CPU 12 **--**--**
# **--**--** Success: station CRBT for 20191126; 2/45870 samples for CPU 23 **--**--**
# **--**--** Success: station P536 for 20200618; 1/45870 samples for CPU 6 **--**--**
# Date 20200611 is not there for station P485
# **--**--** Success: station RDMT for 20200114; 2/45870 samples for CPU 9 **--**--**
# Date 20190931 is not there for station USLO
# **--**--** Success: station P618 for 20200403; 1/45870 samples for CPU 15 **--**--**
# Date 20200327 is not there for station P619
# Date 20190724 is not there for station P505
# **--**--** Success: station P565 for 20190621; 1/45870 samples for CPU 38 **--**--**
# Station CRU1 for date 20190829: time pick failed
# **--**--** Success: station P652 for 20191207; 1/45870 samples for CPU 26 **--**--**
# Date 20200316 is not there for station RHCL
# **--**--** Success: station P474 for 20190821; 2/45870 samples for CPU 3 **--**--**
# Date 20200431 is not there for station SOMT
# Date 20190714 is not there for station P625
# **--**--** Success: station WGPP for 20200217; 1/45870 samples for CPU 35 **--**--**
# Date 20191023 is not there for station VNCX
# Station P523 for date 20200617: time pick failed
# Date 20190718 is not there for station P067
# **--**--** Success: station TJRN for 20190919; 1/45870 samples for CPU 10 **--**--**
# **--**--** Success: station P514 for 20200118; 1/45870 samples for CPU 27 **--**--**
# Date 20200731 is not there for station P288
# **--**--** Success: station P300 for 20200717; 1/45870 samples for CPU 39 **--**--**
# **--**--** Success: station P649 for 20191023; 2/45870 samples for CPU 13 **--**--**
# **--**--** Success: station THCP for 20200327; 1/45870 samples for CPU 28 **--**--**
# Station VDCY for date 20200617: time pick failed
# Date 20191131 is not there for station P640
# **--**--** Success: station P625 for 20200417; 2/45870 samples for CPU 2 **--**--**
# **--**--** Success: station P298 for 20191228; 2/45870 samples for CPU 21 **--**--**
# **--**--** Success: station P742 for 20191117; 2/45870 samples for CPU 33 **--**--**Date 20200311 is not there for station P533
#
# Date 20190902 is not there for station PVRS
# Date 20191013 is not there for station P483
# **--**--** Success: station P468 for 20200105; 2/45870 samples for CPU 1 **--**--**
# **--**--** Success: station P592 for 20200501; 1/45870 samples for CPU 30 **--**--**
# **--**--** Success: station ORMT for 20200712; 2/45870 samples for CPU 10 **--**--**
# **--**--** Success: station P288 for 20200320; 2/45870 samples for CPU 26 **--**--**
# **--**--** Success: station P282 for 20200309; 2/45870 samples for CPU 27 **--**--**
# **--**--** Success: station BILL for 20191021; 3/45870 samples for CPU 13 **--**--**
# **--**--** Success: station HOGS for 20200705; 2/45870 samples for CPU 15 **--**--**
# Date 20190717 is not there for station AR53
# **--**--** Success: station P525 for 20200122; 2/45870 samples for CPU 35 **--**--**
# **--**--** Success: station NDAP for 20191012; 3/45870 samples for CPU 3 **--**--**
# **--**--** Success: station P530 for 20200207; 3/45870 samples for CPU 33 **--**--**
# Date 20191129 is not there for station P281
# Date 20191108 is not there for station P644
# Date 20191026 is not there for station P615
# **--**--** Success: station P525 for 20200724; 1/45870 samples for CPU 31 **--**--**
# Station LGWD for date 20200421: time pick failed
# **--**--** Success: station P560 for 20191226; 1/45870 samples for CPU 16 **--**--**
# Station P563 for date 20190912: time pick failed
# **--**--** Success: station SDHL for 20200520; 2/45870 samples for CPU 34 **--**--**
# Date 20200129 is not there for station P809
# Station BBRY for date 20191127: time pick failed
# Date 20191130 is not there for station P642
# **--**--** Success: station P466 for 20200620; 3/45870 samples for CPU 2 **--**--**
# Date 20200301 is not there for station P463
# **--**--** Success: station DLUZ for 20200328; 2/45870 samples for CPU 38 **--**--**
# Date 20191110 is not there for station SONG
# **--**--** Success: station P536 for 20200504; 2/45870 samples for CPU 20 **--**--**
# Date 20200415 is not there for station P489
# Date 20200310 is not there for station CRHS
# **--**--** Success: station P282 for 20190725; 1/45870 samples for CPU 11 **--**--**
# **--**--** Success: station P288 for 20191029; 2/45870 samples for CPU 6 **--**--**
# **--**--** Success: station P799 for 20191114; 2/45870 samples for CPU 17 **--**--**
# **--**--** Success: station NHRG for 20200507; 4/45870 samples for CPU 2 **--**--**
# **--**--** Success: station P811 for 20200710; 3/45870 samples for CPU 10 **--**--**
# **--**--** Success: station P595 for 20191230; 4/45870 samples for CPU 3 **--**--**
# Date 20190628 is not there for station P537
# Station CAT2 for date 20191227: time pick failed
# Date 20190601 is not there for station SKYB
# **--**--** Success: station RSTP for 20191117; 3/45870 samples for CPU 23 **--**--**
# Date 20190702 is not there for station P281
# **--**--** Success: station P476 for 20200609; 3/45870 samples for CPU 15 **--**--**
# **--**--** Success: station P515 for 20200203; 2/45870 samples for CPU 31 **--**--**
# **--**--** Success: station HOGS for 20200408; 4/45870 samples for CPU 33 **--**--**
# Date 20200329 is not there for station AR53
# **--**--** Success: station CRBT for 20200508; 2/45870 samples for CPU 28 **--**--**
# **--**--** Success: station P741 for 20200402; 4/45870 samples for CPU 13 **--**--**
# Date 20200731 is not there for station P551
# **--**--** Success: station BBRY for 20191228; 1/45870 samples for CPU 5 **--**--**
# **--**--** Success: station P580 for 20200118; 3/45870 samples for CPU 27 **--**--**
# **--**--** Success: station P542 for 20191117; 3/45870 samples for CPU 38 **--**--**
# **--**--** Success: station P093 for 20200201; 1/45870 samples for CPU 8 **--**--**
# **--**--** Success: station P592 for 20200402; 5/45870 samples for CPU 2 **--**--**
# Station RSTP for date 20200430: time pick failed
# Date 20190613 is not there for station P297
# **--**--** Success: station P467 for 20191224; 3/45870 samples for CPU 17 **--**--**
# **--**--** Success: station EWPP for 20190608; 3/45870 samples for CPU 21 **--**--**
# Date 20191111 is not there for station P603
# **--**--** Success: station GMRC for 20200720; 5/45870 samples for CPU 3 **--**--**
# Station BSRY for date 20191011: time pick failed
# Station WGPP for date 20191219: time pick failed
# **--**--** Success: station GMRC for 20191023; 3/45870 samples for CPU 31 **--**--**
# Date 20190818 is not there for station P516
# Station P729 for date 20200518: time pick failed
# **--**--** Success: station VDCY for 20200308; 1/45870 samples for CPU 14 **--**--**
# **--**--** Success: station LDSW for 20191218; 1/45870 samples for CPU 0 **--**--**
# **--**--** Success: station P547 for 20191127; 3/45870 samples for CPU 35 **--**--**
# Date 20190625 is not there for station COPR
# Date 20191211 is not there for station AR27
# Date 20190731 is not there for station P305
# Date 20190804 is not there for station P541
# **--**--** Success: station P514 for 20190629; 1/45870 samples for CPU 22 **--**--**
# **--**--** Success: station RAMT for 20200611; 3/45870 samples for CPU 9 **--**--**
# **--**--** Success: station BEMT for 20191218; 1/45870 samples for CPU 25 **--**--**
# **--**--** Success: station P636 for 20190722; 2/45870 samples for CPU 37 **--**--**
# **--**--** Success: station P583 for 20191005; 4/45870 samples for CPU 15 **--**--**
# Date 20200501 is not there for station SBCC
# Station BSRY for date 20190916: time pick failed
# **--**--** Success: station MPWD for 20191126; 3/45870 samples for CPU 20 **--**--**
# Date 20200310 is not there for station P547
# **--**--** Success: station SKYB for 20200709; 3/45870 samples for CPU 28 **--**--**
# Station VTOR for date 20200406: time pick failed
# Date 20190608 is not there for station P540
# Station P594 for date 20200125: time pick failed
# Date 20191015 is not there for station P278
# Station PBPP for date 20190602: time pick failed
# **--**--** Success: station P551 for 20190609; 4/45870 samples for CPU 38 **--**--**
# Date 20191131 is not there for station PEA1
# **--**--** Success: station BEMT for 20200717; 3/45870 samples for CPU 1 **--**--**
# Date 20191201 is not there for station ACSX
# Date 20190901 is not there for station P491
# Date 20190903 is not there for station ELLY
# **--**--** Success: station HCMN for 20200131; 1/45870 samples for CPU 24 **--**--**
# **--**--** Success: station P618 for 20191019; 4/45870 samples for CPU 9 **--**--**
# Date 20200302 is not there for station P619
# Station P641 for date 20190607: time pick failed
# **--**--** Success: station CBHS for 20200503; 1/45870 samples for CPU 32 **--**--**
# **--**--** Success: station BKAP for 20191002; 2/45870 samples for CPU 32 **--**--**
# **--**--** Success: station P613 for 20190812; 2/45870 samples for CPU 12 **--**--**
# Date 20200311 is not there for station P513
# Date 20190820 is not there for station P567
# Station BILL for date 20200325: time pick failed
# Date 20200121 is not there for station P471
# **--**--** Success: station SKYB for 20200503; 1/45870 samples for CPU 7 **--**--**
# **--**--** Success: station P583 for 20200305; 6/45870 samples for CPU 3 **--**--**
# **--**--** Success: station HCMN for 20191113; 4/45870 samples for CPU 31 **--**--**
# Date 20191009 is not there for station FGST
# **--**--** Success: station P520 for 20190629; 1/45870 samples for CPU 4 **--**--**
# **--**--** Success: station P642 for 20190803; 4/45870 samples for CPU 35 **--**--**
# **--**--** Success: station LDSW for 20200115; 4/45870 samples for CPU 10 **--**--**
# **--**--** Success: station ACSB for 20190831; 4/45870 samples for CPU 28 **--**--**
# **--**--** Success: station P614 for 20190621; 2/45870 samples for CPU 25 **--**--**
# **--**--** Success: station VNCO for 20200625; 5/45870 samples for CPU 15 **--**--**
# **--**--** Success: station THCP for 20200203; 5/45870 samples for CPU 33 **--**--**
# **--**--** Success: station ACSB for 20200406; 5/45870 samples for CPU 13 **--**--**
# **--**--** Success: station P592 for 20200114; 3/45870 samples for CPU 37 **--**--**
# Date 20190731 is not there for station P478
# Date 20200631 is not there for station P725
# Station P476 for date 20200502: time pick failed
# **--**--** Success: station TOST for 20200120; 2/45870 samples for CPU 14 **--**--**
# Date 20200130 is not there for station P488
# Station P627 for date 20190829: time pick failed
# Date 20191211 is not there for station P540
# Date 20190620 is not there for station VTOR
# Station SPMS for date 20190923: time pick failed
# Date 20200309 is not there for station P541
# **--**--** Success: station P532 for 20191221; 2/45870 samples for CPU 22 **--**--**
# Date 20200131 is not there for station P516
# Station SKYB for date 20190907: time pick failed
# Date 20200412 is not there for station BMHL
# **--**--** Success: station P551 for 20200609; 2/45870 samples for CPU 24 **--**--**
# **--**--** Success: station P538 for 20200630; 5/45870 samples for CPU 31 **--**--**
# Date 20191009 is not there for station CDMT
# **--**--** Success: station P583 for 20190930; 7/45870 samples for CPU 3 **--**--**
# Date 20200331 is not there for station P301
# Date 20191001 is not there for station P513
# Date 20191004 is not there for station P174
# Date 20191209 is not there for station P586
# **--**--** Success: station P478 for 20200413; 5/45870 samples for CPU 35 **--**--**
# Date 20191215 is not there for station P281
# **--**--** Success: station HNPS for 20200615; 1/45870 samples for CPU 29 **--**--**
# Station BEMT for date 20190915: time pick failed
# Date 20200631 is not there for station P646
# **--**--** Success: station P568 for 20191227; 2/45870 samples for CPU 7 **--**--**
# Date 20191011 is not there for station ISLK
# Date 20191125 is not there for station P541
# **--**--** Success: station CARH for 20200216; 6/45870 samples for CPU 15 **--**--**
# Station PBPP for date 20191008: time pick failed
# Date 20191102 is not there for station I40A
# Date 20200119 is not there for station P301
# Date 20191223 is not there for station ELLY
# Station SRS1 for date 20191102: time pick failed
# **--**--** Success: station P514 for 20191004; 4/45870 samples for CPU 37 **--**--**
# **--**--** Success: station P466 for 20200721; 3/45870 samples for CPU 14 **--**--**
# **--**--** Success: station HUNT for 20190617; 5/45870 samples for CPU 28 **--**--**
# **--**--** Success: station P515 for 20190923; 6/45870 samples for CPU 13 **--**--**
# Date 20200509 is not there for station COPR
# Station VTOR for date 20200120: time pick failed
# Date 20200111 is not there for station P809
# Station P616 for date 20200424: time pick failed
# Date 20190720 is not there for station P809**--**--** Success: station P591 for 20191024; 4/45870 samples for CPU 1 **--**--**
#
# Date 20200712 is not there for station ANA1Date 20200524 is not there for station COPR
#
# **--**--** Success: station MNMC for 20200227; 5/45870 samples for CPU 1 **--**--**
# Station CRBT for date 20200213: time pick failed
# Date 20200516 is not there for station FMVT
# Date 20200303 is not there for station SLMS
# **--**--** Success: station CSCI for 20190607; 4/45870 samples for CPU 20 **--**--**
# Date 20191020 is not there for station P809**--**--** Success: station VNCX for 20190914; 6/45870 samples for CPU 31 **--**--**
#
# Date 20200512 is not there for station P284
# Date 20200726 is not there for station P586
# Station P646 for date 20191010: time pick failed
# Date 20200505 is not there for station ANA1
# Station RSVY for date 20200109: time pick failed
# **--**--** Success: station BBDM for 20200702; 1/45870 samples for CPU 19 **--**--**
# **--**--** Success: station P302 for 20190911; 3/45870 samples for CPU 32 **--**--**
# **--**--** Success: station CDMT for 20191106; 6/45870 samples for CPU 35 **--**--**
# Station P548 for date 20191229: time pick failed
# **--**--** Success: station ACSX for 20191220; 3/45870 samples for CPU 26 **--**--**
# **--**--** Success: station BVPP for 20200621; 2/45870 samples for CPU 29 **--**--**
# Date 20190713 is not there for station P582
# Station SPMS for date 20200119: time pick failed
# **--**--** Success: station P725 for 20190728; 4/45870 samples for CPU 14 **--**--**
# **--**--** Success: station P511 for 20200709; 3/45870 samples for CPU 7 **--**--**
# Date 20200225 is not there for station AZU1
# Date 20191216 is not there for station P281
# Station P641 for date 20200416: time pick failed
# Date 20200111 is not there for station P488
# Date 20191210 is not there for station WOMT
# Date 20200530 is not there for station P810
# **--**--** Success: station P305 for 20200403; 3/45870 samples for CPU 22 **--**--**
# Date 20191031 is not there for station ANA1
# **--**--** Success: station HUNT for 20200721; 7/45870 samples for CPU 13 **--**--**
# **--**--** Success: station HUNT for 20200416; 6/45870 samples for CPU 28 **--**--**
# Date 20191201 is not there for station P505
# Date 20200517 is not there for station RHCL
# Date 20200124 is not there for station P279
# Date 20200704 is not there for station P579
# Station P567 for date 20200718: time pick failed
# Date 20200631 is not there for station AZU1
# Station BKMS for date 20191027: time pick failed
# **--**--** Success: station P542 for 20190816; 4/45870 samples for CPU 17 **--**--**
# **--**--** Success: station P304 for 20200308; 3/45870 samples for CPU 6 **--**--**
# **--**--** Success: station P282 for 20200212; 4/45870 samples for CPU 32 **--**--**
# Station VIMT for date 20200106: time pick failed
# **--**--** Success: station ISLK for 20190628; 2/45870 samples for CPU 39 **--**--**
# **--**--** Success: station P520 for 20200215; 7/45870 samples for CPU 35 **--**--**
# **--**--** Success: station RAMT for 20191225; 1/45870 samples for CPU 36 **--**--**
# **--**--** Success: station ORES for 20191213; 6/45870 samples for CPU 33 **--**--**
# **--**--** Success: station MUSB for 20200305; 3/45870 samples for CPU 29 **--**--**
# **--**--** Success: station P511 for 20190626; 2/45870 samples for CPU 16 **--**--**
# Station P654 for date 20200518: time pick failed
# **--**--** Success: station P525 for 20200320; 3/45870 samples for CPU 34 **--**--**
# **--**--** Success: station P742 for 20200221; 7/45870 samples for CPU 31 **--**--**
# Date 20190813 is not there for station P516
# Date 20200231 is not there for station P278
# **--**--** Success: station P621 for 20190725; 4/45870 samples for CPU 23 **--**--****--**--** Success: station CARH for 20200403; 5/45870 samples for CPU 10 **--**--**
#
# Date 20191007 is not there for station RMVJ
# Date 20190903 is not there for station P533
# **--**--** Success: station OVLS for 20200624; 2/45870 samples for CPU 5 **--**--**
# **--**--** Success: station P553 for 20200418; 3/45870 samples for CPU 24 **--**--**
# Date 20191106 is not there for station FGST
# 20190707 gets skipped - earthquake day
# **--**--** Success: station ACSX for 20191205; 5/45870 samples for CPU 37 **--**--**
# **--**--** Success: station CNPP for 20191024; 2/45870 samples for CPU 4 **--**--**
# Date 20200321 is not there for station P281
# **--**--** Success: station P525 for 20190924; 5/45870 samples for CPU 14 **--**--**
# Station P525 for date 20200220: time pick failed
# Date 20190615 is not there for station CPBN
# **--**--** Success: station MAT2 for 20191002; 5/45870 samples for CPU 9 **--**--**
# Date 20191130 is not there for station P280
# **--**--** Success: station P484 for 20191214; 5/45870 samples for CPU 38 **--**--**
# **--**--** Success: station P518 for 20190709; 1/45870 samples for CPU 18 **--**--**
# **--**--** Success: station P298 for 20190710; 3/45870 samples for CPU 25 **--**--**
# Station OCSD for date 20190722: time pick failed
# Date 20200526 is not there for station P520
# Date 20200212 is not there for station CLBD
# **--**--** Success: station P589 for 20200504; 4/45870 samples for CPU 22 **--**--**
# **--**--** Success: station P615 for 20190821; 3/45870 samples for CPU 39 **--**--**
# Date 20200202 is not there for station P488
# Date 20200325 is not there for station P582
# **--**--** Success: station CTDM for 20191228; 2/45870 samples for CPU 19 **--**--**
# Date 20200330 is not there for station P646
# Date 20200527 is not there for station P636
# Station BVPP for date 20200603: time pick failed
# Date 20190710 is not there for station P483
# Date 20200309 is not there for station P281
# 20190707 gets skipped - earthquake day
# Station P622 for date 20191018: time pick failed
# **--**--** Success: station P636 for 20200712; 4/45870 samples for CPU 21 **--**--**
# **--**--** Success: station P563 for 20200104; 4/45870 samples for CPU 34 **--**--**
# Date 20190908 is not there for station P625
# Date 20200607 is not there for station P810
# **--**--** Success: station BEPK for 20200407; 5/45870 samples for CPU 20 **--**--**
# **--**--** Success: station P580 for 20200221; 4/45870 samples for CPU 7 **--**--**
# Station P462 for date 20191011: time pick failed
# Station BKMS for date 20191120: time pick failed
# **--**--** Success: station P742 for 20200502; 8/45870 samples for CPU 35 **--**--**
# **--**--** Success: station I40A for 20190914; 6/45870 samples for CPU 37 **--**--**
# Date 20190808 is not there for station PVRS
# Date 20200319 is not there for station P537
# **--**--** Success: station P606 for 20190926; 4/45870 samples for CPU 29 **--**--**
# **--**--** Success: station VNCX for 20200313; 4/45870 samples for CPU 39 **--**--**
# 20190822 gets skipped - earthquake day
# **--**--** Success: station CAT3 for 20191117; 5/45870 samples for CPU 32 **--**--**
# Station BBRY for date 20191029: time pick failed
# **--**--** Success: station P567 for 20200226; 5/45870 samples for CPU 34 **--**--**
# Station P630 for date 20200609: time pick failed
# Date 20190713 is not there for station MIG1
# **--**--** Success: station CCCC for 20191115; 3/45870 samples for CPU 12 **--**--**
# **--**--** Success: station CDMT for 20200101; 3/45870 samples for CPU 19 **--**--**
# Station LDSW for date 20200428: time pick failed
# **--**--** Success: station P056 for 20191224; 5/45870 samples for CPU 39 **--**--**
# **--**--** Success: station P491 for 20190727; 6/45870 samples for CPU 39 **--**--**
# Date 20200718 is not there for station HIVI
# Station P622 for date 20200614: time pick failed
# **--**--** Success: station P552 for 20200131; 9/45870 samples for CPU 35 **--**--**
# **--**--** Success: station P514 for 20191120; 6/45870 samples for CPU 32 **--**--**
# Date 20191210 is not there for station COPR
# Date 20200110 is not there for station P504
# Date 20191201 is not there for station P740
# **--**--** Success: station RCSC for 20200110; 3/45870 samples for CPU 4 **--**--**
# **--**--** Success: station P621 for 20191122; 7/45870 samples for CPU 37 **--**--**
# Date 20190631 is not there for station P470
# Station P630 for date 20200403: time pick failed
# **--**--** Success: station P652 for 20200502; 7/45870 samples for CPU 15 **--**--**
# **--**--** Success: station P611 for 20191226; 5/45870 samples for CPU 7 **--**--**
# **--**--** Success: station ISLK for 20190907; 7/45870 samples for CPU 39 **--**--**
# **--**--** Success: station P093 for 20190701; 6/45870 samples for CPU 1 **--**--**
# **--**--** Success: station P593 for 20190723; 8/45870 samples for CPU 3 **--**--**
# **--**--** Success: station BEMT for 20190626; 7/45870 samples for CPU 28 **--**--**
# **--**--** Success: station P742 for 20190811; 5/45870 samples for CPU 21 **--**--**
# **--**--** Success: station P642 for 20190916; 4/45870 samples for CPU 25 **--**--**
# Station P478 for date 20191219: time pick failed
# Station P539 for date 20190913: time pick failed
# Date 20190629 is not there for station P516
# Date 20191026 is not there for station P290
# Date 20191212 is not there for station P629
# Date 20191010 is not there for station CAND
# Date 20200301 is not there for station CDMT
# Date 20190725 is not there for station ISLK
# Date 20190616 is not there for station THMS
# **--**--** Success: station PEA1 for 20190617; 6/45870 samples for CPU 34 **--**--**
# Station P522 for date 20190717: time pick failed
# Date 20200623 is not there for station P487
# Station BSRY for date 20200715: time pick failed
# Date 20190820 is not there for station P485
# Station P729 for date 20200429: time pick failed
# **--**--** Success: station ORES for 20200527; 7/45870 samples for CPU 33 **--**--**
# **--**--** Success: station P511 for 20191203; 5/45870 samples for CPU 23 **--**--**
# **--**--** Success: station ECFS for 20200118; 3/45870 samples for CPU 16 **--**--**
# **--**--** Success: station RSTP for 20191127; 6/45870 samples for CPU 9 **--**--**
# Station TONO for date 20200525: time pick failed
# Station OCSD for date 20190811: time pick failed
# 20190726 gets skipped - earthquake day
# **--**--** Success: station P593 for 20200223; 6/45870 samples for CPU 38 **--**--**
# Date 20200217 is not there for station P486
# Station P606 for date 20200611: time pick failed
# **--**--** Success: station P056 for 20200214; 8/45870 samples for CPU 13 **--**--**
# Date 20200407 is not there for station P285
# Date 20190820 is not there for station P614
# Date 20191003 is not there for station P513
# **--**--** Success: station KBRC for 20190813; 5/45870 samples for CPU 29 **--**--**
# Date 20200612 is not there for station ANA1
# **--**--** Success: station P627 for 20190614; 2/45870 samples for CPU 8 **--**--**
# **--**--** Success: station P741 for 20190905; 2/45870 samples for CPU 11 **--**--**
# Date 20191021 is not there for station P809
# Station P636 for date 20200430: time pick failed
# Date 20190828 is not there for station P604
# Date 20191201 is not there for station P513
# **--**--** Success: station I40A for 20200102; 4/45870 samples for CPU 16 **--**--**
# **--**--** Success: station HNPS for 20200515; 9/45870 samples for CPU 3 **--**--**
# **--**--** Success: station P602 for 20200503; 7/45870 samples for CPU 1 **--**--**
# **--**--** Success: station P093 for 20190813; 7/45870 samples for CPU 38 **--**--**
# Station P579 for date 20191113: time pick failed
# **--**--** Success: station P579 for 20200315; 8/45870 samples for CPU 39 **--**--**
# **--**--** Success: station LGWD for 20191029; 2/45870 samples for CPU 30 **--**--**
# **--**--** Success: station HNPS for 20200206; 4/45870 samples for CPU 12 **--**--**
# Date 20191031 is not there for station SBCC
# Date 20200112 is not there for station P482
# **--**--** Success: station TJRN for 20190918; 5/45870 samples for CPU 16 **--**--**
# Station BKMS for date 20200117: time pick failed
# **--**--** Success: station P742 for 20200725; 3/45870 samples for CPU 30 **--**--**
# Date 20200110 is not there for station THMS
# **--**--** Success: station MNMC for 20200502; 4/45870 samples for CPU 30 **--**--**
# Date 20200216 is not there for station MIG1
# Station MIDA for date 20191230: time pick failed
# **--**--** Success: station BEPK for 20190916; 5/45870 samples for CPU 12 **--**--**
# Station P557 for date 20190903: time pick failed
# Date 20190931 is not there for station CRBT
# **--**--** Success: station GMRC for 20191116; 3/45870 samples for CPU 11 **--**--**
# Date 20200309 is not there for station ANA1
# Station ORMT for date 20200213: time pick failed
# **--**--** Success: station P245 for 20190728; 4/45870 samples for CPU 6 **--**--**
# Date 20200715 is not there for station P471
# **--**--** Success: station P611 for 20191012; 6/45870 samples for CPU 12 **--**--**
# **--**--** Success: station P551 for 20191230; 9/45870 samples for CPU 39 **--**--**
# Date 20191123 is not there for station GR8R
# **--**--** Success: station P627 for 20200406; 4/45870 samples for CPU 11 **--**--**
# **--**--** Success: station HNPS for 20200724; 3/45870 samples for CPU 5 **--**--**
# Date 20200602 is not there for station P642
# Date 20200527 is not there for station THCP
# Date 20200516 is not there for station P577
# Date 20191005 is not there for station CARH
# **--**--** Success: station P811 for 20191220; 10/45870 samples for CPU 39 **--**--**
# Date 20191005 is not there for station PVRS
# **--**--** Success: station P800 for 20190817; 7/45870 samples for CPU 12 **--**--**
# Station P636 for date 20191114: time pick failed
# Date 20190614 is not there for station P462
# Date 20190708 is not there for station P636
# **--**--** Success: station ACSB for 20200122; 5/45870 samples for CPU 6 **--**--**
# Date 20190914 is not there for station P487
# **--**--** Success: station P546 for 20190802; 2/45870 samples for CPU 36 **--**--**
# **--**--** Success: station PKRD for 20190626; 4/45870 samples for CPU 5 **--**--**
# **--**--** Success: station P552 for 20190624; 6/45870 samples for CPU 23 **--**--**
# **--**--** Success: station P521 for 20200624; 2/45870 samples for CPU 18 **--**--**
# Date 20200601 is not there for station AR53
# **--**--** Success: station P521 for 20200624; 5/45870 samples for CPU 17 **--**--**
# **--**--** Success: station P304 for 20200303; 11/45870 samples for CPU 39 **--**--**
# **--**--** Success: station P800 for 20200413; 6/45870 samples for CPU 16 **--**--**
# Date 20191006 is not there for station P545
# **--**--** Success: station CSST for 20200227; 10/45870 samples for CPU 35 **--**--**
# Date 20200322 is not there for station COPR
# **--**--** Success: station THCP for 20191206; 7/45870 samples for CPU 9 **--**--**
# **--**--** Success: station P479 for 20200420; 6/45870 samples for CPU 6 **--**--**
# Date 20200410 is not there for station BMHL
# Station P290 for date 20200423: time pick failed
# 20190823 gets skipped - earthquake day
# Date 20200520 is not there for station P297
# **--**--** Success: station ISLK for 20190929; 3/45870 samples for CPU 8 **--**--**
# **--**--** Success: station P527 for 20200522; 5/45870 samples for CPU 22 **--**--**
# Date 20191218 is not there for station P586
# Date 20200410 is not there for station P648
# Station P622 for date 20190720: time pick failed
# **--**--** Success: station P511 for 20190627; 6/45870 samples for CPU 7 **--**--****--**--** Success: station ACSX for 20191001; 6/45870 samples for CPU 10 **--**--**
#
# **--**--** Success: station VNCO for 20190715; 4/45870 samples for CPU 26 **--**--**
# **--**--** Success: station DSSC for 20190727; 6/45870 samples for CPU 2 **--**--**
# **--**--** Success: station CRU1 for 20200624; 5/45870 samples for CPU 30 **--**--**
# Station P539 for date 20200416: time pick failed
# **--**--** Success: station RDMT for 20200217; 9/45870 samples for CPU 13 **--**--**
# **--**--** Success: station P304 for 20190614; 8/45870 samples for CPU 33 **--**--**
# Date 20190819 is not there for station P642
# Date 20200202 is not there for station AR27
# **--**--** Success: station P468 for 20200518; 8/45870 samples for CPU 38 **--**--**
# Date 20191201 is not there for station P489
# Date 20190911 is not there for station P504
# **--**--** Success: station P602 for 20190814; 6/45870 samples for CPU 29 **--**--**
# Date 20190908 is not there for station ECFS
# Date 20200101 is not there for station P581
# **--**--** Success: station P467 for 20190612; 8/45870 samples for CPU 12 **--**--**
# **--**--** Success: station P637 for 20190907; 7/45870 samples for CPU 34 **--**--**
# **--**--** Success: station P527 for 20190813; 3/45870 samples for CPU 36 **--**--**
# **--**--** Success: station P463 for 20200226; 8/45870 samples for CPU 15 **--**--**
# Date 20190924 is not there for station P297
# Station P641 for date 20200211: time pick failed
# **--**--** Success: station CARH for 20200505; 4/45870 samples for CPU 24 **--**--**
# Date 20200511 is not there for station P529
# **--**--** Success: station P538 for 20190910; 10/45870 samples for CPU 3 **--**--**
# **--**--** Success: station P280 for 20200518; 8/45870 samples for CPU 1 **--**--**
# **--**--** Success: station P554 for 20200201; 7/45870 samples for CPU 16 **--**--**
# Date 20190717 is not there for station P603
# **--**--** Success: station P564 for 20200703; 7/45870 samples for CPU 7 **--**--**
# Date 20190601 is not there for station P471
# **--**--** Success: station P577 for 20200212; 7/45870 samples for CPU 10 **--**--**
# 20190706 gets skipped - earthquake day
# **--**--** Success: station P570 for 20200311; 10/45870 samples for CPU 13 **--**--**
# **--**--** Success: station OCSD for 20200711; 6/45870 samples for CPU 21 **--**--**
# Date 20191028 is not there for station P483
# Station HCMN for date 20200603: time pick failed
# **--**--** Success: station LAND for 20200211; 2/45870 samples for CPU 0 **--**--**
# **--**--** Success: station P284 for 20191219; 6/45870 samples for CPU 14 **--**--**
# **--**--** Success: station P591 for 20190803; 5/45870 samples for CPU 26 **--**--**
# Date 20200527 is not there for station P607
# **--**--** Success: station P479 for 20200116; 7/45870 samples for CPU 29 **--**--**
# Station RMVJ for date 20200622: time pick failed
# Date 20190929 is not there for station VDCY
# 20190706 gets skipped - earthquake day
# Date 20200124 is not there for station P606
# Date 20190720 is not there for station P629
# **--**--** Success: station P647 for 20190805; 8/45870 samples for CPU 9 **--**--**
# Date 20200124 is not there for station P641
# **--**--** Success: station BKAP for 20200524; 4/45870 samples for CPU 8 **--**--**
# Date 20190720 is not there for station P489
# **--**--** Success: station P644 for 20200417; 8/45870 samples for CPU 31 **--**--**
# Date 20191101 is not there for station P278
# **--**--** Success: station BBRY for 20200304; 9/45870 samples for CPU 33 **--**--**
# Station BEPK for date 20190925: time pick failed
# **--**--** Success: station P527 for 20190925; 5/45870 samples for CPU 24 **--**--**
# **--**--** Success: station OVLS for 20191202; 8/45870 samples for CPU 7 **--**--**
# **--**--** Success: station CRBT for 20190831; 9/45870 samples for CPU 12 **--**--**
# **--**--** Success: station SCIA for 20191017; 5/45870 samples for CPU 8 **--**--**
# Date 20190820 is not there for station P565**--**--** Success: station P647 for 20191113; 4/45870 samples for CPU 36 **--**--**
# **--**--** Success: station LFRS for 20190730; 5/45870 samples for CPU 5 **--**--**
#
# Date 20190714 is not there for station SHOS
# **--**--** Success: station P640 for 20200312; 8/45870 samples for CPU 10 **--**--**
# Date 20200530 is not there for station P554
# Date 20200306 is not there for station P650
# Date 20190931 is not there for station P551
# **--**--** Success: station P466 for 20200723; 5/45870 samples for CPU 11 **--**--**
# Station CRHS for date 20191205: time pick failed
# Station P590 for date 20191020: time pick failed
# **--**--** Success: station P552 for 20200501; 6/45870 samples for CPU 30 **--**--**
# Station P300 for date 20200507: time pick failed
# Date 20200301 is not there for station P308
# **--**--** Success: station P556 for 20200406; 9/45870 samples for CPU 9 **--**--**
# 20190712 gets skipped - earthquake day
# Date 20191129 is not there for station WOMT
# **--**--** Success: station OVLS for 20191206; 4/45870 samples for CPU 27 **--**--**
# Date 20190615 is not there for station TOST
# **--**--** Success: station P546 for 20200617; 4/45870 samples for CPU 19 **--**--**
# **--**--** Success: station P470 for 20200416; 10/45870 samples for CPU 33 **--**--**
# Station RHCL for date 20200622: time pick failed
# **--**--** Success: station P474 for 20200328; 4/45870 samples for CPU 4 **--**--**
# Date 20200212 is not there for station P619
# Date 20191009 is not there for station MNMC
# Station P476 for date 20191105: time pick failed
# **--**--** Success: station P527 for 20200127; 6/45870 samples for CPU 26 **--**--**
# **--**--** Success: station P618 for 20190916; 9/45870 samples for CPU 15 **--**--**
# Date 20200617 is not there for station P603
# **--**--** Success: station P521 for 20191012; 6/45870 samples for CPU 24 **--**--**
# Date 20190728 is not there for station P489
# Station P634 for date 20191105: time pick failed
# **--**--** Success: station P463 for 20200224; 9/45870 samples for CPU 7 **--**--**
# 20190706 gets skipped - earthquake day
# Date 20190720 is not there for station P278
# **--**--** Success: station P654 for 20200717; 10/45870 samples for CPU 12 **--**--**
# **--**--** Success: station P639 for 20191204; 6/45870 samples for CPU 11 **--**--**
# Station CLBD for date 20190831: time pick failed
# Station BVPP for date 20190714: time pick failed
# Date 20191130 is not there for station P598
# **--**--** Success: station P740 for 20200627; 7/45870 samples for CPU 23 **--**--**
# **--**--** Success: station P606 for 20200322; 6/45870 samples for CPU 8 **--**--**
# Date 20190731 is not there for station P301
# **--**--** Success: station P463 for 20191123; 9/45870 samples for CPU 10 **--**--**
# **--**--** Success: station P602 for 20190605; 10/45870 samples for CPU 9 **--**--**
# **--**--** Success: station P590 for 20190605; 12/45870 samples for CPU 39 **--**--**
# Station P607 for date 20190724: time pick failed
# **--**--** Success: station DSSC for 20190717; 6/45870 samples for CPU 20 **--**--**
# Date 20200405 is not there for station P516
# **--**--** Success: station P484 for 20190718; 5/45870 samples for CPU 25 **--**--**
# Station P598 for date 20190629: time pick failed
# **--**--** Success: station P463 for 20190729; 5/45870 samples for CPU 27 **--**--**
# **--**--** Success: station P613 for 20200128; 8/45870 samples for CPU 29 **--**--**
# Date 20200121 is not there for station SHOS
# Date 20200206 is not there for station P488
# **--**--** Success: station P556 for 20190621; 5/45870 samples for CPU 19 **--**--**
# Date 20191002 is not there for station P297
# Date 20200307 is not there for station P653
# Station P557 for date 20190628: time pick failed
# **--**--** Success: station MLFP for 20200612; 7/45870 samples for CPU 26 **--**--**
# Date 20191024 is not there for station P800
# Date 20200527 is not there for station P621
# **--**--** Success: station OZST for 20190814; 7/45870 samples for CPU 6 **--**--**
# **--**--** Success: station IMPS for 20200329; 7/45870 samples for CPU 24 **--**--**
# **--**--** Success: station P742 for 20200705; 8/45870 samples for CPU 34 **--**--**
# **--**--** Success: station IMPS for 20200206; 6/45870 samples for CPU 5 **--**--**
# Station P470 for date 20190812: time pick failed
# Date 20200505 is not there for station P603
# Date 20200431 is not there for station SLMS
# Date 20191224 is not there for station P532
# **--**--** Success: station P595 for 20190910; 11/45870 samples for CPU 12 **--**--**
# **--**--** Success: station P653 for 20191207; 7/45870 samples for CPU 30 **--**--**
# **--**--** Success: station CAND for 20200614; 6/45870 samples for CPU 22 **--**--**
# **--**--** Success: station PEA2 for 20190908; 3/45870 samples for CPU 18 **--**--**
# Station P536 for date 20200325: time pick failed
# Station LORS for date 20191010: time pick failed
# **--**--** Success: station P627 for 20200114; 7/45870 samples for CPU 2 **--**--**
# **--**--** Success: station RHCL for 20190906; 6/45870 samples for CPU 27 **--**--**
# **--**--** Success: station CAT3 for 20200417; 6/45870 samples for CPU 17 **--**--**
# Date 20191031 is not there for station P515
# Date 20200106 is not there for station P809
# **--**--** Success: station P590 for 20200715; 5/45870 samples for CPU 36 **--**--**
# Station HUNT for date 20200113: time pick failed
# Date 20200402 is not there for station P471
# **--**--** Success: station P591 for 20200708; 9/45870 samples for CPU 29 **--**--**
# **--**--** Success: station RAMT for 20200129; 6/45870 samples for CPU 19 **--**--**
# Date 20200531 is not there for station P290
# Date 20190631 is not there for station RDMT
# Station P527 for date 20191221: time pick failed
# Station P056 for date 20191020: time pick failed
# Station BEMT for date 20191022: time pick failed
# Date 20200731 is not there for station P630
# **--**--** Success: station RDMT for 20200313; 8/45870 samples for CPU 30 **--**--**
# **--**--** Success: station VNCX for 20200704; 9/45870 samples for CPU 34 **--**--**
# **--**--** Success: station P611 for 20200714; 10/45870 samples for CPU 7 **--**--**
# Date 20200513 is not there for station P581
# **--**--** Success: station P491 for 20190727; 11/45870 samples for CPU 7 **--**--**
# **--**--** Success: station CSCI for 20191019; 7/45870 samples for CPU 5 **--**--**
# **--**--** Success: station P621 for 20190918; 11/45870 samples for CPU 9 **--**--**
# **--**--** Success: station P563 for 20200621; 12/45870 samples for CPU 12 **--**--**
# **--**--** Success: station RAMT for 20200219; 11/45870 samples for CPU 13 **--**--**
# **--**--** Success: station P511 for 20191115; 11/45870 samples for CPU 3 **--**--**
# **--**--** Success: station P595 for 20190724; 11/45870 samples for CPU 33 **--**--**
# Station P511 for date 20191028: time pick failed
# **--**--** Success: station P091 for 20191116; 7/45870 samples for CPU 32 **--**--**
# **--**--** Success: station P552 for 20200302; 13/45870 samples for CPU 39 **--**--**
# **--**--** Success: station P527 for 20200204; 9/45870 samples for CPU 1 **--**--**
# **--**--** Success: station P621 for 20190605; 11/45870 samples for CPU 35 **--**--**
# Date 20191009 is not there for station P632
# Station P634 for date 20200418: time pick failed
# **--**--** Success: station CNPP for 20191104; 8/45870 samples for CPU 28 **--**--**
# Date 20191022 is not there for station P800
# 20190704 gets skipped - earthquake day
# Date 20190826 is not there for station P582
# Date 20191117 is not there for station P586
# **--**--** Success: station P557 for 20200129; 9/45870 samples for CPU 31 **--**--**
# **--**--** Success: station BILL for 20200716; 8/45870 samples for CPU 37 **--**--**
# **--**--** Success: station P288 for 20200515; 7/45870 samples for CPU 17 **--**--**
# Date 20191022 is not there for station SLMS
# Date 20190921 is not there for station P279
# Date 20190826 is not there for station CDMT
# Date 20190901 is not there for station P648
# Date 20191129 is not there for station P593
# **--**--** Success: station CSST for 20190729; 4/45870 samples for CPU 18 **--**--**
# Date 20191006 is not there for station VIMT
# Station P546 for date 20190615: time pick failed
# **--**--** Success: station HVYS for 20190815; 6/45870 samples for CPU 25 **--**--**
# Date 20191009 is not there for station OZST
# Date 20191104 is not there for station P297
# **--**--** Success: station P491 for 20200210; 14/45870 samples for CPU 39 **--**--**
# Station P522 for date 20200501: time pick failed
# Date 20200525 is not there for station PEA2
# **--**--** Success: station WGPP for 20200426; 12/45870 samples for CPU 9 **--**--**
# Date 20200401 is not there for station FGST
# Date 20190623 is not there for station P533
# Date 20200609 is not there for station P537
# **--**--** Success: station P470 for 20200713; 13/45870 samples for CPU 12 **--**--**
# **--**--** Success: station P463 for 20200319; 8/45870 samples for CPU 16 **--**--**
# Date 20190628 is not there for station SONG
# **--**--** Success: station P476 for 20200311; 12/45870 samples for CPU 7 **--**--****--**--** Success: station P552 for 20200403; 12/45870 samples for CPU 13 **--**--**
#
# Date 20191007 is not there for station GR8R
# Station P515 for date 20200428: time pick failed
# **--**--** Success: station P282 for 20200308; 12/45870 samples for CPU 33 **--**--**
# **--**--** Success: station P557 for 20200305; 12/45870 samples for CPU 3 **--**--**
# Date 20191203 is not there for station EWPP
# **--**--** Success: station P740 for 20191006; 10/45870 samples for CPU 10 **--**--**
# Date 20200610 is not there for station P584
# **--**--** Success: station P302 for 20191220; 8/45870 samples for CPU 32 **--**--**
# **--**--** Success: station P606 for 20200502; 8/45870 samples for CPU 26 **--**--**
# **--**--** Success: station P627 for 20190811; 10/45870 samples for CPU 34 **--**--**
# Date 20200403 is not there for station FGST
# **--**--** Success: station P525 for 20190831; 7/45870 samples for CPU 22 **--**--**
# **--**--** Success: station P468 for 20190906; 10/45870 samples for CPU 31 **--**--**
# Date 20190907 is not there for station COPR
# Station P608 for date 20191125: time pick failed
# Station P289 for date 20200429: time pick failed
# 20200604 gets skipped - earthquake day
# **--**--** Success: station RCSC for 20200720; 10/45870 samples for CPU 29 **--**--**
# Date 20190730 is not there for station ELLY
# **--**--** Success: station P532 for 20191004; 5/45870 samples for CPU 18 **--**--****--**--** Success: station P621 for 20190616; 8/45870 samples for CPU 17 **--**--**
#
# **--**--** Success: station P592 for 20200706; 14/45870 samples for CPU 12 **--**--**
# **--**--** Success: station P290 for 20200108; 13/45870 samples for CPU 33 **--**--**
# **--**--** Success: station P608 for 20200105; 13/45870 samples for CPU 9 **--**--**
# Date 20190820 is not there for station P741
# Date 20190631 is not there for station BBDM
# Station P551 for date 20190803: time pick failed
# Station P633 for date 20190802: time pick failed
# **--**--** Success: station P568 for 20200426; 9/45870 samples for CPU 37 **--**--**
# **--**--** Success: station CNPP for 20190727; 15/45870 samples for CPU 39 **--**--**
# **--**--** Success: station CRBT for 20200619; 13/45870 samples for CPU 3 **--**--**
# **--**--** Success: station RNCH for 20190922; 8/45870 samples for CPU 5 **--**--**
# **--**--** Success: station P476 for 20200327; 7/45870 samples for CPU 8 **--**--**
# Date 20191205 is not there for station SONG
# **--**--** Success: station P093 for 20191016; 9/45870 samples for CPU 28 **--**--**
# **--**--** Success: station P542 for 20191221; 11/45870 samples for CPU 31 **--**--****--**--** Success: station ACSX for 20191011; 11/45870 samples for CPU 34 **--**--**
#
# Date 20200230 is not there for station P281
# **--**--** Success: station P474 for 20191125; 7/45870 samples for CPU 20 **--**--**
# **--**--** Success: station P504 for 20200713; 11/45870 samples for CPU 10 **--**--**
# Station ORMT for date 20190815: time pick failed
# **--**--** Success: station CAND for 20200308; 7/45870 samples for CPU 19 **--**--**
# Date 20191217 is not there for station P646
# **--**--** Success: station P725 for 20190613; 7/45870 samples for CPU 25 **--**--**
# Date 20190919 is not there for station P488
# Date 20190608 is not there for station WKPK
# **--**--** Success: station DSSC for 20190905; 9/45870 samples for CPU 38 **--**--**
# **--**--** Success: station CBHS for 20190915; 11/45870 samples for CPU 29 **--**--**
# **--**--** Success: station ACSX for 20190621; 10/45870 samples for CPU 1 **--**--**
# Date 20191110 is not there for station P584
# Date 20191113 is not there for station P522
# Date 20200403 is not there for station P603
# 20190712 gets skipped - earthquake day
# Station OZST for date 20200622: time pick failed
# Date 20191007 is not there for station P579
# ...
# Date 20190623 is not there for station P654
# Date 20191108 is not there for station P629
# **--**--** Success: station LDES for 20200713; 203/45870 samples for CPU 35 **--**--**
# **--**--** Success: station CRU1 for 20200405; 176/45870 samples for CPU 25 **--**--**
# **--**--** Success: station P546 for 20191204; 177/45870 samples for CPU 25 **--**--**
# **--**--** Success: station P797 for 20200705; 175/45870 samples for CPU 19 **--**--**
# **--**--** Success: station P511 for 20191123; 214/45870 samples for CPU 11 **--**--**
# **--**--** Success: station ORES for 20190630; 192/45870 samples for CPU 9 **--**--**
# **--**--** Success: station BMHL for 20190818; 199/45870 samples for CPU 21 **--**--**
# **--**--** Success: station CPBN for 20200125; 186/45870 samples for CPU 23 **--**--**
# **--**--** Success: station BBRY for 20200626; 181/45870 samples for CPU 38 **--**--**
# Date 20200301 is not there for station ANA1
# **--**--** Success: station P478 for 20191002; 195/45870 samples for CPU 20 **--**--**
# **--**--** Success: station CNPP for 20200506; 195/45870 samples for CPU 13 **--**--**
# Date 20191124 is not there for station P516
# Date 20200507 is not there for station P279
# Station BBRY for date 20190623: time pick failedDate 20200517 is not there for station RSTP
#
# Date 20200616 is not there for station P619
# Station VIMT for date 20190804: time pick failed
# **--**--** Success: station NDAP for 20191005; 196/45870 samples for CPU 13 **--**--**
# Date 20200703 is not there for station HIVI
# **--**--** Success: station LDSW for 20200517; 182/45870 samples for CPU 38 **--**--**
# **--**--** Success: station P479 for 20191123; 201/45870 samples for CPU 24 **--**--**
# **--**--** Success: station LDSW for 20200627; 192/45870 samples for CPU 0 **--**--**
# Date 20200501 is not there for station P648
# Station BKMS for date 20190627: time pick failed
# **--**--** Success: station MUSB for 20191106; 143/45870 samples for CPU 7 **--**--**
# Date 20190617 is not there for station P604
# **--**--** Success: station P519 for 20190727; 194/45870 samples for CPU 31 **--**--**
# 20190705 gets skipped - earthquake day
# Date 20191027 is not there for station P532
# Station BSRY for date 20191008: time pick failed
# **--**--** Success: station P290 for 20191225; 185/45870 samples for CPU 22 **--**--**
# **--**--** Success: station P811 for 20191115; 180/45870 samples for CPU 4 **--**--**
# Date 20200326 is not there for station CRHS
# Date 20191007 is not there for station P612
# Date 20190825 is not there for station AZU1
# Date 20200411 is not there for station P489
# Date 20200730 is not there for station ELLY
# **--**--** Success: station P797 for 20190618; 194/45870 samples for CPU 36 **--**--**
# Station TJRN for date 20191106: time pick failed
# **--**--** Success: station P800 for 20191205; 190/45870 samples for CPU 29 **--**--**
# **--**--** Success: station P298 for 20191101; 163/45870 samples for CPU 26 **--**--**
# **--**--** Success: station P630 for 20191111; 204/45870 samples for CPU 12 **--**--**
# Date 20191015 is not there for station P619
# **--**--** Success: station NDAP for 20190606; 190/45870 samples for CPU 37 **--**--**
# Date 20191223 is not there for station P637
# Date 20191113 is not there for station P621
# **--**--** Success: station P551 for 20190701; 177/45870 samples for CPU 14 **--**--**
# **--**--** Success: station P591 for 20200501; 173/45870 samples for CPU 34 **--**--**
# **--**--** Success: station P536 for 20191002; 188/45870 samples for CPU 10 **--**--**
# Date 20200114 is not there for station SONG
# Date 20200101 is not there for station P639
# Station P474 for date 20200518: time pick failed
# Date 20190831 is not there for station AR53
# Date 20200515 is not there for station THCP
# **--**--** Success: station MIDA for 20190627; 192/45870 samples for CPU 5 **--**--**Date 20200231 is not there for station RHCL
#
# Station P300 for date 20190717: time pick failed
# Date 20200111 is not there for station P619
# 20190704 gets skipped - earthquake day
# 20190704 gets skipped - earthquake day
# **--**--** Success: station HUNT for 20190722; 173/45870 samples for CPU 30 **--**--**
# **--**--** Success: station SONG for 20200624; 189/45870 samples for CPU 2 **--**--**
# Date 20191118 is not there for station P281
# Date 20200512 is not there for station PBPP
# Station P634 for date 20191015: time pick failed
# Date 20191211 is not there for station AR27
# Station CRHS for date 20200526: time pick failed
# **--**--** Success: station P304 for 20200321; 215/45870 samples for CPU 11 **--**--**
# **--**--** Success: station P612 for 20200613; 207/45870 samples for CPU 1 **--**--**
# Date 20200704 is not there for station P586
# Station BSRY for date 20190626: time pick failed
# Date 20191003 is not there for station THMS
# **--**--** Success: station P812 for 20191003; 202/45870 samples for CPU 24 **--**--**
# **--**--** Success: station CRBT for 20191229; 208/45870 samples for CPU 1 **--**--**
# **--**--** Success: station VNCO for 20200726; 178/45870 samples for CPU 25 **--**--**
# Date 20200106 is not there for station P582
# **--**--** Success: station P630 for 20200115; 176/45870 samples for CPU 19 **--**--**
# Date 20190803 is not there for station P644
# Date 20191214 is not there for station P568
# **--**--** Success: station P484 for 20191014; 179/45870 samples for CPU 25 **--**--**
# **--**--** Success: station P650 for 20191220; 180/45870 samples for CPU 25 **--**--**
# Date 20191124 is not there for station P607
# **--**--** Success: station P289 for 20190830; 196/45870 samples for CPU 20 **--**--**
# **--**--** Success: station BBDM for 20200508; 219/45870 samples for CPU 33 **--**--****--**--** Success: station P613 for 20190905; 187/45870 samples for CPU 23 **--**--**
#
# Date 20200124 is not there for station THCP
# Date 20200104 is not there for station P586
# Date 20190713 is not there for station P654
# Date 20200205 is not there for station P537
# Date 20191025 is not there for station P630
# Station P305 for date 20191107: time pick failed
# Station P590 for date 20190928: time pick failed
# Date 20190631 is not there for station SRS1
# Date 20200523 is not there for station P488
# **--**--** Success: station TONO for 20200527; 180/45870 samples for CPU 16 **--**--**
# Date 20200523 is not there for station PBPP
# Date 20200216 is not there for station P797
# **--**--** Success: station TONO for 20191101; 183/45870 samples for CPU 38 **--**--**
# Date 20190607 is not there for station P245
# Date 20190728 is not there for station P489
# **--**--** Success: station BEPK for 20200523; 195/45870 samples for CPU 31 **--**--**
# Station P556 for date 20200501: time pick failed
# **--**--** Success: station HCMN for 20200720; 212/45870 samples for CPU 3 **--**--**
# Date 20200425 is not there for station THCP
# **--**--** Success: station P650 for 20190714; 213/45870 samples for CPU 3 **--**--**
# **--**--** Success: station P539 for 20200103; 214/45870 samples for CPU 3 **--**--**
# Date 20190820 is not there for station WOMT
# **--**--** Success: station HVYS for 20200224; 144/45870 samples for CPU 7 **--**--**
# Date 20200419 is not there for station HIVI**--**--** Success: station PEA2 for 20200112; 181/45870 samples for CPU 4 **--**--**
#
# Date 20191006 is not there for station P486
# Station P642 for date 20200121: time pick failed
# **--**--** Success: station P547 for 20191203; 191/45870 samples for CPU 37 **--**--**
# Station CLBD for date 20190613: time pick failed
# Date 20191201 is not there for station LAND
# **--**--** Success: station ECFS for 20200204; 164/45870 samples for CPU 26 **--**--**
# **--**--** Success: station HOGS for 20191209; 165/45870 samples for CPU 26 **--**--**
# Station P476 for date 20190908: time pick failed
# 20190716 gets skipped - earthquake day
# Date 20200416 is not there for station COPR
# Station P622 for date 20190811: time pick failed
# **--**--** Success: station P570 for 20200626; 218/45870 samples for CPU 18 **--**--**
# Date 20190809 is not there for station P553
# Date 20191008 is not there for station P646
# Station BKMS for date 20190811: time pick failed
# **--**--** Success: station TOST for 20191202; 177/45870 samples for CPU 19 **--**--**
# **--**--** Success: station BILL for 20191010; 181/45870 samples for CPU 25 **--**--**
# **--**--** Success: station SDHL for 20191127; 190/45870 samples for CPU 2 **--**--**
# **--**--** Success: station CNPP for 20190619; 189/45870 samples for CPU 32 **--**--**
# Date 20191013 is not there for station P490
# Date 20200430 is not there for station P581
# **--**--** Success: station P595 for 20190904; 178/45870 samples for CPU 19 **--**--**
# Date 20190825 is not there for station P537
# Date 20191111 is not there for station ISLK
# 20190716 gets skipped - earthquake day
# **--**--** Success: station P611 for 20200702; 209/45870 samples for CPU 1 **--**--**
# Date 20200603 is not there for station SONG
# Station DSSC for date 20200326: time pick failedDate 20190717 is not there for station P727
#
# Date 20200603 is not there for station P303
# Station P522 for date 20200530: time pick failed
# **--**--** Success: station P538 for 20200713; 174/45870 samples for CPU 30 **--**--**
# **--**--** Success: station P612 for 20200113; 216/45870 samples for CPU 11 **--**--**
# **--**--** Success: station P551 for 20200424; 198/45870 samples for CPU 28 **--**--**
# **--**--** Success: station ORES for 20190717; 181/45870 samples for CPU 27 **--**--**
# Date 20191201 is not there for station P541
# Date 20191224 is not there for station TOST
# **--**--** Success: station MIDA for 20190628; 193/45870 samples for CPU 0 **--**--**
# **--**--** Success: station P478 for 20190818; 188/45870 samples for CPU 15 **--**--**
# **--**--** Success: station WGPP for 20200123; 190/45870 samples for CPU 39 **--**--**
# **--**--** Success: station LDES for 20200401; 197/45870 samples for CPU 20 **--**--**
# Date 20200421 is not there for station P809
# Station LGWD for date 20191101: time pick failed
# **--**--** Success: station P616 for 20200128; 197/45870 samples for CPU 13 **--**--**
# Date 20200218 is not there for station GR8R
# Date 20190731 is not there for station PKRD
# **--**--** Success: station ACSB for 20191016; 198/45870 samples for CPU 13 **--**--**
# **--**--** Success: station CSST for 20190614; 203/45870 samples for CPU 24 **--**--**
# **--**--** Success: station SDHL for 20191208; 189/45870 samples for CPU 10 **--**--**
# **--**--** Success: station P811 for 20200509; 190/45870 samples for CPU 10 **--**--**
# Station VIMT for date 20190919: time pick failed
# Date 20191031 is not there for station SKYB
# **--**--** Success: station P552 for 20200415; 195/45870 samples for CPU 36 **--**--**
# Station FMVT for date 20200628: time pick failed
# **--**--** Success: station P593 for 20191225; 145/45870 samples for CPU 7 **--**--**
# Date 20200420 is not there for station GR8R
# **--**--** Success: station TJRN for 20190621; 182/45870 samples for CPU 4 **--**--**
# **--**--** Success: station P648 for 20200705; 205/45870 samples for CPU 12 **--**--**
# **--**--** Success: station BBDM for 20200528; 186/45870 samples for CPU 22 **--**--**
# **--**--** Success: station P468 for 20200329; 200/45870 samples for CPU 21 **--**--**
# **--**--** Success: station P288 for 20200217; 193/45870 samples for CPU 9 **--**--**
# Date 20200103 is not there for station P647
# **--**--** Success: station P583 for 20191124; 174/45870 samples for CPU 17 **--**--**
# Station RCA2 for date 20200111: time pick failed
# **--**--** Success: station P591 for 20190729; 182/45870 samples for CPU 25 **--**--**
# **--**--** Success: station P280 for 20191128; 217/45870 samples for CPU 11 **--**--**
# **--**--** Success: station P479 for 20190619; 184/45870 samples for CPU 38 **--**--**
# Date 20200301 is not there for station RSVY
# **--**--** Success: station P470 for 20191127; 210/45870 samples for CPU 1 **--**--**
# **--**--** Success: station P282 for 20200501; 191/45870 samples for CPU 2 **--**--**
# Date 20200615 is not there for station CRHS
# Station P611 for date 20200425: time pick failed
# **--**--** Success: station LAND for 20200508; 175/45870 samples for CPU 8 **--**--**
# **--**--** Success: station P304 for 20200129; 199/45870 samples for CPU 28 **--**--**
# **--**--** Success: station P504 for 20200312; 188/45870 samples for CPU 23 **--**--**
# **--**--** Success: station BBRY for 20200328; 204/45870 samples for CPU 35 **--**--**
# Date 20200610 is not there for station P625
# **--**--** Success: station SKYB for 20200206; 178/45870 samples for CPU 14 **--**--**
# Date 20200314 is not there for station HIVI
# Station P484 for date 20200118: time pick failed
# **--**--** Success: station HNPS for 20191028; 191/45870 samples for CPU 29 **--**--**
# **--**--** Success: station LAND for 20190602; 198/45870 samples for CPU 20 **--**--**
# **--**--** Success: station P546 for 20191114; 192/45870 samples for CPU 29 **--**--**
# Date 20190714 is not there for station P488
# **--**--** Success: station I40A for 20200115; 183/45870 samples for CPU 25 **--**--**
# Date 20200631 is not there for station WKPK
# Date 20190901 is not there for station P477
# Date 20200204 is not there for station HIVI
# Date 20190617 is not there for station P532**--**--** Success: station CNPP for 20200730; 181/45870 samples for CPU 16 **--**--****--**--** Success: station P542 for 20190807; 205/45870 samples for CPU 35 **--**--**
#
#
# Date 20200129 is not there for station P471
# Date 20191226 is not there for station COPR
# Date 20191017 is not there for station ELLY
# Date 20191103 is not there for station CDMT
# **--**--** Success: station I40A for 20200704; 179/45870 samples for CPU 19 **--**--**
# **--**--** Success: station P557 for 20200223; 189/45870 samples for CPU 23 **--**--**
# 20190707 gets skipped - earthquake day
# **--**--** Success: station P548 for 20200507; 192/45870 samples for CPU 37 **--**--**
# Date 20200111 is not there for station SHOS
# Date 20191020 is not there for station P725
# **--**--** Success: station EWPP for 20200529; 185/45870 samples for CPU 38 **--**--**
# **--**--** Success: station RMVJ for 20200426; 200/45870 samples for CPU 28 **--**--**
# Date 20200513 is not there for station P557
# **--**--** Success: station CRBT for 20191229; 201/45870 samples for CPU 28 **--**--**
# **--**--** Success: station P620 for 20200401; 206/45870 samples for CPU 35 **--**--**
# **--**--** Success: station P056 for 20191030; 207/45870 samples for CPU 35 **--**--**
# **--**--** Success: station BMHL for 20191115; 176/45870 samples for CPU 8 **--**--**
# **--**--** Success: station BMHL for 20190813; 218/45870 samples for CPU 11 **--**--**
# **--**--** Success: station P812 for 20200316; 182/45870 samples for CPU 16 **--**--**
# Station P556 for date 20200403: time pick failedDate 20190825 is not there for station P298
#
# Date 20190629 is not there for station P504
# Date 20190703 is not there for station P091
# **--**--** Success: station P611 for 20200103; 186/45870 samples for CPU 38 **--**--**
# Date 20191018 is not there for station SLMS
# Date 20200526 is not there for station WGPP
# Date 20200519 is not there for station P809
# Station P812 for date 20200322: time pick failed
# Station P639 for date 20200626: time pick failed
# Date 20190631 is not there for station P490
# Date 20200306 is not there for station P525
# Date 20191106 is not there for station SRS1
# **--**--** Success: station SCIA for 20200217; 208/45870 samples for CPU 35 **--**--**
# **--**--** Success: station HVYS for 20190617; 199/45870 samples for CPU 20 **--**--**
# Date 20190922 is not there for station P487
# Date 20200623 is not there for station HNPS
# **--**--** Success: station P579 for 20190630; 193/45870 samples for CPU 5 **--**--**
# Station VTOR for date 20200108: time pick failed
# Date 20200722 is not there for station MIG1
# Date 20200513 is not there for station VIMT
# Date 20200506 is not there for station RHCL
# Date 20190728 is not there for station P489
# Station NHRG for date 20200421: time pick failed
# Date 20200305 is not there for station AR27
# Date 20190624 is not there for station ELLY
# **--**--** Success: station P740 for 20200415; 190/45870 samples for CPU 23 **--**--**
# Station RCSC for date 20191025: time pick failed
