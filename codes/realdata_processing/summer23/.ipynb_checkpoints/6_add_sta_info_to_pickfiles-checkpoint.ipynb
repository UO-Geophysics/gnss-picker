# %%
from obspy.clients.fdsn import Client
from obspy import UTCDateTime
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import os

minmag = 4.3

project = 'summer23'
project_dir = '/hdd/Ridgecrest/' + project + '/'
pick_files_dir = project_dir + 'minM' + str(minmag) + '_event_pick_files/'
picks_w_stainfo_dir = pick_files_dir + 'picks_w_stainfo/'
p_dir = picks_w_stainfo_dir + 'p_picks/'
s_dir = picks_w_stainfo_dir + 's_picks/'

if os.path.isdir(picks_w_stainfo_dir):
    pass
else:
    os.makedirs(picks_w_stainfo_dir)
    os.makedirs(p_dir)
    os.makedirs(s_dir)

event_catalog = np.genfromtxt(project_dir + 'minM' + str(minmag) + '_event_catalog.txt', dtype = 'U')
# print(event_catalog)
event_IDs = event_catalog[:,0]

small_test = False

if small_test:
    event_IDs = ['38472279', '37219156']
# Out:
# 362

# %%
starttime = UTCDateTime("2019-06-01T00:00:00")
endtime = UTCDateTime("2020-07-30T23:59:59")

client = Client("SCEDC")
inventory = client.get_stations(network = "CI,PB", station = "*", channel = '*', starttime = starttime,
                                endtime = endtime, latitude = 35.7695, longitude = -117.5993333, maxradius = 10)

# %%
CI_network = inventory.networks[0].get_contents()
CI_sta_len = np.arange(len(CI_network['stations']))

CI_sta_list = []
CI_sta_lat = []
CI_sta_lon = []
CI_sta_elev = []

for ksta in CI_sta_len:
    
    sta_code = inventory[0][ksta].code
    sta_lat = inventory[0][ksta].latitude
    sta_lon = inventory[0][ksta].longitude
    sta_elev = inventory[0][ksta].elevation
    
    CI_sta_list.append(sta_code)
    CI_sta_lat.append(sta_lat)
    CI_sta_lon.append(sta_lon)
    CI_sta_elev.append(sta_elev)

CI_sta_list_array = np.array(CI_sta_list)
CI_sta_lat_array = np.array(CI_sta_lat)
CI_sta_lon_array = np.array(CI_sta_lon)
CI_sta_elev_array = np.array(CI_sta_elev)

CI_info_array = np.column_stack((CI_sta_list_array, CI_sta_lat_array, CI_sta_lon_array, CI_sta_elev_array))
print(CI_info_array.shape)
# Out:
# (430, 4)

# %%
PB_network = inventory.networks[1].get_contents()
PB_sta_len = np.arange(len(PB_network['stations']))

PB_sta_list = []
PB_sta_lat = []
PB_sta_lon = []
PB_sta_elev = []

for ksta in PB_sta_len:
    
    sta_code = inventory[1][ksta].code
    sta_lat = inventory[1][ksta].latitude
    sta_lon = inventory[1][ksta].longitude
    sta_elev = inventory[1][ksta].elevation
    
    PB_sta_list.append(sta_code)
    PB_sta_lat.append(sta_lat)
    PB_sta_lon.append(sta_lon)
    PB_sta_elev.append(sta_elev)

PB_sta_list_array = np.array(PB_sta_list)
# print(PB_sta_list_array)
PB_sta_lat_array = np.array(PB_sta_lat)
PB_sta_lon_array = np.array(PB_sta_lon)
PB_sta_elev_array = np.array(PB_sta_elev)

PB_info_array = np.column_stack((PB_sta_list_array, PB_sta_lat_array, PB_sta_lon_array, PB_sta_elev_array))
print(PB_info_array.shape)
# Out:
# (53, 4)

# %%
z = 0
p = 0 
s = 0

for event_ID in event_IDs:
    
    # print(event_ID)
    
    P_eventID_list = []
    P_picktime_list = []
    P_net_list = []
    P_sta_list = []
    P_chan_list = []
    P_stalat_list = []
    P_stalon_list = []
    P_staelev_list = []
    
    S_eventID_list = []
    S_picktime_list = []
    S_net_list = []
    S_sta_list = []
    S_chan_list = []
    S_stalat_list = []
    S_stalon_list = []
    S_staelev_list = []
        
    pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
    # print(pick_file)
    
    num_rows = np.arange(len(pick_file))
    # print(num_rows)
    
    for num_row in num_rows:
        
        # print('-------------------------------')
        pick_row = pick_file[num_row]
        # print(pick_row)
        
        pick_time = pick_row[0]
        net = pick_row[1]
        sta = pick_row[2]
        chan = pick_row[3]
        
        # print(chan[2])
        
        # print(pick_time)
        # print(net)
        # print(sta)
        # print(chan)
        
        # Picks on vertical - P-wave arrival
        
        if chan[2] == 'Z':
            
            # print('Vertical channel')
            
            if net == 'CI':
            
                i = np.where(CI_sta_list_array == sta)[0]
                # print(len(i))
                
                if len(i) > 0:
                    
                    # print(CI_info_array[i][0])
                    # print(CI_info_array[i][0][0])
                    # print(CI_info_array[i][0][1])
                    # print(CI_info_array[i][0][2])
                    # print(CI_info_array[i][0][3])
                    
                    P_eventID_list.append(event_ID)
                    P_picktime_list.append(pick_time)
                    P_net_list.append(net)
                    P_sta_list.append(sta)
                    P_chan_list.append(chan)
                    P_stalat_list.append(CI_info_array[i][0][1])
                    P_stalon_list.append(CI_info_array[i][0][2])
                    P_staelev_list.append(CI_info_array[i][0][3])

                else:
                    pass
                    # print("CI Z error:")
                    # print(sta)
            
            elif net == 'PB':
                
                i = np.where(PB_sta_list_array == sta)[0]
                # print(len(i))
                
                if len(i) > 0:
                    
                    # print(PB_info_array[i][0])
                    
                    P_eventID_list.append(event_ID)
                    P_picktime_list.append(pick_time)
                    P_net_list.append(net)
                    P_sta_list.append(sta)
                    P_chan_list.append(chan)
                    P_stalat_list.append(PB_info_array[i][0][1])
                    P_stalon_list.append(PB_info_array[i][0][2])
                    P_staelev_list.append(PB_info_array[i][0][3])
                
                else:
                    pass
                    # print("PB Z error:")
                    # print(sta)
                
            else:
                # print('Not CI or PB')
                pass
        
        # Picks on horizontal - S-wave arrival
        
        if chan[2] == 'N' or chan[2] == 'E' or chan[2] == '1' or chan[2] == '2':
            
            # print('Horizontal channel')
        
            if net == 'CI':
                
                i = np.where(CI_sta_list_array == sta)[0]
                # print(i)
                
                if len(i) > 0:
                    
                    # print(CI_info_array[i][0])
                    
                    S_eventID_list.append(event_ID)
                    S_picktime_list.append(pick_time)
                    S_net_list.append(net)
                    S_sta_list.append(sta)
                    S_chan_list.append(chan)
                    S_stalat_list.append(CI_info_array[i][0][1])
                    S_stalon_list.append(CI_info_array[i][0][2])
                    S_staelev_list.append(CI_info_array[i][0][3])
                
                else:
                    pass
                    # print("CI H error:")
                    # print(sta)
            
            elif net == 'PB':
                
                i = np.where(PB_sta_list_array == sta)[0]
                # print(i)
                
                if len(i) > 0:
                    
                    # print(PB_info_array[i][0])
                    
                    S_eventID_list.append(event_ID)
                    S_picktime_list.append(pick_time)
                    S_net_list.append(net)
                    S_sta_list.append(sta)
                    S_chan_list.append(chan)
                    S_stalat_list.append(PB_info_array[i][0][1])
                    S_stalon_list.append(PB_info_array[i][0][2])
                    S_staelev_list.append(PB_info_array[i][0][3])
                
                else:
                    pass
                    # print("PB H error:")
                    # print(sta)
                               
            else:
                pass
                # print('Not CI or PB')

    print('-------------------------')
    print('EVENT ' + str(event_ID))
    print('-------------------------')

    P_array = np.column_stack((np.array(P_eventID_list), np.array(P_picktime_list), np.array(P_net_list), np.array(P_sta_list), np.array(P_chan_list), np.array(P_stalat_list), np.array(P_stalon_list), np.array(P_staelev_list)))
    # print(P_array)
    
    if len(P_array) == 0:
        p += 1
        
    print('P-wave picks: ' + str(len(P_array)))
    # print(P_array[0])
    np.save(p_dir + str(event_ID) + '.npy', P_array) # LAP
    
    S_array = np.column_stack((np.array(S_eventID_list), np.array(S_picktime_list), np.array(S_net_list), np.array(S_sta_list), np.array(S_chan_list), np.array(S_stalat_list), np.array(S_stalon_list), np.array(S_staelev_list)))
    # print(S_array)
    
    if len(S_array) == 0:
        s += 1
        
    print('S-wave picks: ' + str(len(S_array)))
    # print(S_array[0])
    np.save(s_dir + str(event_ID) + '.npy', S_array) # LAP
    
    if len(P_array) == 0 and len(S_array) == 0:
        z += 1
    
    # print(' ')
    
print(z)
print(p)
print(s)
# Out:
# -------------------------
# EVENT 37451589
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37451541
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37451501
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37451477
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37451309
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37451149
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37450997
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37450989
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37450933
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37450925
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37450917
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37450909
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37450901
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37450893
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37450717
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37450613
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37450605
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37450597
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 38592034
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37450541
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37450309
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37449909
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37449877
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 39281127
# -------------------------
# P-wave picks: 24
# S-wave picks: 3
# -------------------------
# EVENT 37449853
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37449845
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37449837
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37449757
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 39273567
# -------------------------
# P-wave picks: 30
# S-wave picks: 3
# -------------------------
# EVENT 37448549
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37447901
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 39494008
# -------------------------
# P-wave picks: 32
# S-wave picks: 32
# -------------------------
# EVENT 39493944
# -------------------------
# P-wave picks: 35
# S-wave picks: 32
# -------------------------
# EVENT 37447701
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37447677
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37447637
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 39490952
# -------------------------
# P-wave picks: 123
# S-wave picks: 42
# -------------------------
# EVENT 37447517
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37447509
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37447501
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 39486360
# -------------------------
# P-wave picks: 10
# S-wave picks: 9
# -------------------------
# EVENT 39485504
# -------------------------
# P-wave picks: 4
# S-wave picks: 2
# -------------------------
# EVENT 37447437
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37447317
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37447309
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37447101
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37447077
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37446725
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 39462536
# -------------------------
# P-wave picks: 124
# S-wave picks: 71
# -------------------------
# EVENT 37446677
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37446669
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37446573
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 39223887
# -------------------------
# P-wave picks: 67
# S-wave picks: 0
# -------------------------
# EVENT 37446517
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37451589.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37451541.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37451501.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37451477.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37451309.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37451149.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37450997.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37450989.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37450933.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37450925.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37450917.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37450909.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37450901.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37450893.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37450717.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37450613.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37450605.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37450597.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/38592034.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37450541.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37450309.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37449909.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37449877.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37449853.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37449845.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37449837.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37449757.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37448549.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37447901.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37447701.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37447677.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37447637.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37447517.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37447509.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37447501.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37447437.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37447317.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37447309.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37447101.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37447077.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37446725.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37446677.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37446669.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37446573.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37446517.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37446493.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37446245.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37446125.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37445997.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37445965.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37445829.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# -------------------------
# EVENT 39223791
# -------------------------
# P-wave picks: 35
# S-wave picks: 8
# -------------------------
# EVENT 39223527
# -------------------------
# P-wave picks: 25
# S-wave picks: 0
# -------------------------
# EVENT 37446493
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37446245
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37446125
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37445997
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37445965
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37445829
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37445989
# -------------------------
# P-wave picks: 4
# S-wave picks: 3
# -------------------------
# EVENT 39208087
# -------------------------
# P-wave picks: 196
# S-wave picks: 2
# -------------------------
# EVENT 39207503
# -------------------------
# P-wave picks: 140
# S-wave picks: 2
# -------------------------
# EVENT 37445709
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 39205383
# -------------------------
# P-wave picks: 5
# S-wave picks: 4
# -------------------------
# EVENT 39205151
# -------------------------
# P-wave picks: 144
# S-wave picks: 3
# -------------------------
# EVENT 39204599
# -------------------------
# P-wave picks: 4
# S-wave picks: 3
# -------------------------
# EVENT 39203167
# -------------------------
# P-wave picks: 4
# S-wave picks: 3
# -------------------------
# EVENT 39202623
# -------------------------
# P-wave picks: 124
# S-wave picks: 4
# -------------------------
# EVENT 37445661
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 39202175
# -------------------------
# P-wave picks: 91
# S-wave picks: 4
# -------------------------
# EVENT 39201767
# -------------------------
# P-wave picks: 3
# S-wave picks: 0
# -------------------------
# EVENT 39201559
# -------------------------
# P-wave picks: 4
# S-wave picks: 3
# -------------------------
# EVENT 37445637
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 39201407
# -------------------------
# P-wave picks: 34
# S-wave picks: 0
# -------------------------
# EVENT 39201279
# -------------------------
# P-wave picks: 3
# S-wave picks: 1
# -------------------------
# EVENT 39201263
# -------------------------
# P-wave picks: 3
# S-wave picks: 0
# -------------------------
# EVENT 39201231
# -------------------------
# P-wave picks: 39
# S-wave picks: 0
# -------------------------
# EVENT 39201215
# -------------------------
# P-wave picks: 53
# S-wave picks: 3
# -------------------------
# EVENT 39201199
# -------------------------
# P-wave picks: 26
# S-wave picks: 4
# -------------------------
# EVENT 37445565
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37445485
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37445349
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 38488354
# -------------------------
# P-wave picks: 90
# S-wave picks: 78
# -------------------------
# EVENT 37445189
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37445061
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37444965
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37444581
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37444565
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37444397
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37444389
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37443197
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37443101
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37442525
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37442517
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37442221
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37442133
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37441981
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37441613
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 39382736
# -------------------------
# P-wave picks: 7
# S-wave picks: 5
# -------------------------
# EVENT 39382424
# -------------------------
# P-wave picks: 3
# S-wave picks: 3
# -------------------------
# EVENT 39126079
# -------------------------
# P-wave picks: 132
# S-wave picks: 103
# -------------------------
# EVENT 37439981
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37439237
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37439269
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37439069
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 39111991
# -------------------------
# P-wave picks: 30
# S-wave picks: 30
# -------------------------
# EVENT 37438781
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 39106919
# -------------------------
# P-wave picks: 12
# S-wave picks: 3
# -------------------------
# EVENT 37438301
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37438229
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37438101
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37437773
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37436797
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 38388202
# -------------------------
# P-wave picks: 1
# S-wave picks: 1
# -------------------------
# EVENT 38388106
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 38385946
# -------------------------
# P-wave picks: 8
# S-wave picks: 1
# -------------------------
# EVENT 37436565
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37435485
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37435357
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37435149
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37434957
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37434365
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37434141
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37434133
# -------------------------
# P-wave picks: 0
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37445709.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37445661.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37445637.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37445565.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37445485.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37445349.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37445189.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37445061.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37444965.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37444581.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37444565.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37444397.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37444389.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37443197.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37443101.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37442525.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37442517.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37442221.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37442133.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37441981.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37441613.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37439981.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37439237.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37439269.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37439069.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37438781.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37438301.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37438229.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37438101.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37437773.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37436797.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/38388106.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37436565.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37435485.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37435357.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37435149.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37434957.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37434365.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37434141.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37434133.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37434045.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# S-wave picks: 0
# -------------------------
# EVENT 37434045
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37433957
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37433909
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37433645
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 39289104
# -------------------------
# P-wave picks: 74
# S-wave picks: 17
# -------------------------
# EVENT 37433421
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37433397
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37433381
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37433373
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37433413
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37433349
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37433341
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37433389
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37433333
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37433325
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 39281440
# -------------------------
# P-wave picks: 39
# S-wave picks: 32
# -------------------------
# EVENT 37433237
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37433213
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37433085
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37433053
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432957
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432949
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432941
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432933
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432925
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432869
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432765
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432485
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432469
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432453
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432365
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432341
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432333
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432325
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432317
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432301
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432293
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432269
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432181
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432173
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432149
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432141
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432125
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432093
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432077
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432069
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432053
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37432045
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37431941
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37431909
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37431805
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 39233472
# -------------------------
# P-wave picks: 12
# S-wave picks: 10
# -------------------------
# EVENT 37431701
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37431693
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37431413
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37431357
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37431253
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37431101
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37431085
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37431069
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37431061
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37431053
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37431045
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37431029
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37431021
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37430965
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37430957
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37430949
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37430765
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37430485
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37430445
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37430285
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37430205
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37430101
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37430013
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37430005
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37430477
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37429861
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37429853
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37429821
# -------------------------
# P-wave picks: 0
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37433957.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37433909.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37433645.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37433421.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37433397.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37433381.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37433373.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37433413.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37433349.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37433341.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37433389.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37433333.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37433325.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37433237.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37433213.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37433085.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37433053.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37432957.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37432949.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37432941.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37432933.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37432925.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37432869.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37432765.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37432485.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37432469.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37432453.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37432365.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37432341.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# ...
# -------------------------
# P-wave picks: 257
# S-wave picks: 48
# -------------------------
# EVENT 38463551
# -------------------------
# P-wave picks: 255
# S-wave picks: 47
# -------------------------
# EVENT 38460983
# -------------------------
# P-wave picks: 175
# S-wave picks: 46
# -------------------------
# EVENT 38460975
# -------------------------
# P-wave picks: 52
# S-wave picks: 31
# -------------------------
# EVENT 38460967
# -------------------------
# P-wave picks: 253
# S-wave picks: 38
# -------------------------
# EVENT 38460311
# -------------------------
# P-wave picks: 302
# S-wave picks: 38
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37421477.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37421389.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37421381.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37421373.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37421261.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37421117.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420989.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420861.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# -------------------------
# EVENT 38458679
# -------------------------
# P-wave picks: 245
# S-wave picks: 61
# -------------------------
# EVENT 38458079
# -------------------------
# P-wave picks: 94
# S-wave picks: 38
# -------------------------
# EVENT 38458071
# -------------------------
# P-wave picks: 31
# S-wave picks: 25
# -------------------------
# EVENT 37224964
# -------------------------
# P-wave picks: 20
# S-wave picks: 20
# -------------------------
# EVENT 38457967
# -------------------------
# P-wave picks: 155
# S-wave picks: 14
# -------------------------
# EVENT 38457847
# -------------------------
# P-wave picks: 197
# S-wave picks: 49
# -------------------------
# EVENT 38457815
# -------------------------
# P-wave picks: 54
# S-wave picks: 53
# -------------------------
# EVENT 38457775
# -------------------------
# P-wave picks: 147
# S-wave picks: 40
# -------------------------
# EVENT 37421229
# -------------------------
# P-wave picks: 28
# S-wave picks: 26
# -------------------------
# EVENT 38457703
# -------------------------
# P-wave picks: 38
# S-wave picks: 33
# -------------------------
# EVENT 38457687
# -------------------------
# P-wave picks: 162
# S-wave picks: 53
# -------------------------
# EVENT 38457615
# -------------------------
# P-wave picks: 110
# S-wave picks: 26
# -------------------------
# EVENT 38457591
# -------------------------
# P-wave picks: 35
# S-wave picks: 44
# -------------------------
# EVENT 38457583
# -------------------------
# P-wave picks: 12
# S-wave picks: 23
# -------------------------
# EVENT 37219564
# -------------------------
# P-wave picks: 6
# S-wave picks: 6
# -------------------------
# EVENT 37219180
# -------------------------
# P-wave picks: 12
# S-wave picks: 26
# -------------------------
# EVENT 37219172
# -------------------------
# P-wave picks: 23
# S-wave picks: 33
# -------------------------
# EVENT 37219164
# -------------------------
# P-wave picks: 23
# S-wave picks: 41
# -------------------------
# EVENT 37219468
# -------------------------
# P-wave picks: 11
# S-wave picks: 10
# -------------------------
# EVENT 37219156
# -------------------------
# P-wave picks: 18
# S-wave picks: 27
# -------------------------
# EVENT 37219500
# -------------------------
# P-wave picks: 6
# S-wave picks: 6
# -------------------------
# EVENT 37219492
# -------------------------
# P-wave picks: 3
# S-wave picks: 7
# -------------------------
# EVENT 37219484
# -------------------------
# P-wave picks: 13
# S-wave picks: 22
# -------------------------
# EVENT 38457519
# -------------------------
# P-wave picks: 21
# S-wave picks: 23
# -------------------------
# EVENT 37222204
# -------------------------
# P-wave picks: 13
# S-wave picks: 12
# -------------------------
# EVENT 37222196
# -------------------------
# P-wave picks: 5
# S-wave picks: 13
# -------------------------
# EVENT 37222188
# -------------------------
# P-wave picks: 4
# S-wave picks: 4
# -------------------------
# EVENT 38457511
# -------------------------
# P-wave picks: 71
# S-wave picks: 16
# -------------------------
# EVENT 38457487
# -------------------------
# P-wave picks: 292
# S-wave picks: 46
# -------------------------
# EVENT 37420709
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 38450263
# -------------------------
# P-wave picks: 156
# S-wave picks: 67
# -------------------------
# EVENT 38445087
# -------------------------
# P-wave picks: 226
# S-wave picks: 63
# -------------------------
# EVENT 38443871
# -------------------------
# P-wave picks: 205
# S-wave picks: 53
# -------------------------
# EVENT 38443719
# -------------------------
# P-wave picks: 205
# S-wave picks: 86
# -------------------------
# EVENT 38443647
# -------------------------
# P-wave picks: 161
# S-wave picks: 60
# -------------------------
# EVENT 38443607
# -------------------------
# P-wave picks: 190
# S-wave picks: 52
# -------------------------
# EVENT 38443535
# -------------------------
# P-wave picks: 53
# S-wave picks: 41
# -------------------------
# EVENT 38443191
# -------------------------
# P-wave picks: 41
# S-wave picks: 41
# -------------------------
# EVENT 38443183
# -------------------------
# P-wave picks: 190
# S-wave picks: 38
# -------------------------
# EVENT 37420677
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37420597
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37420541
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37420413
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37420405
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37420397
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37420389
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37420381
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37420349
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37420317
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37420309
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37420301
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 38426607
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37420293
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37420285
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37420277
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37420269
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37420253
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37420221
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37420197
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37420141
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37420101
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37419973
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37419965
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37419957
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37419949
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37419853
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 38640920
# -------------------------
# P-wave picks: 11
# S-wave picks: 2
# -------------------------
# EVENT 38624424
# -------------------------
# P-wave picks: 165
# S-wave picks: 35
# -------------------------
# EVENT 37419405
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# -------------------------
# EVENT 37419349
# -------------------------
# P-wave picks: 0
# S-wave picks: 0
# 264
# 264
# 270
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420709.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420677.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420597.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420541.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420413.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420405.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420397.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420389.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420381.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420349.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420317.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420309.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420301.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420293.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420285.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420277.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420269.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420253.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420221.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420197.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420141.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37420101.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37419973.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37419965.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37419957.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37419949.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37419853.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37419405.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
# <ipython-input-5-dea7470fcf5b>:27: UserWarning: genfromtxt: Empty input file: "/hdd/Ridgecrest/summer23/minM4.3_event_pick_files/37419349.pick"
#   pick_file = np.genfromtxt(pick_files_dir + str(event_ID) + '.pick', dtype = 'U')
